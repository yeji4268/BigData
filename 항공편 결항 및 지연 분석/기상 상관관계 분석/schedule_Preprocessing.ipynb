# %% [markdown]
# ## 항공 스케줄 데이터 : 데이터 전처리
# ---
# * 제주공항에서 출발하는 항공편의 목적지
#     + 광주공항
#     + 김포공항
#     + 김해공항
#     + 청주공항
# ---
# ### 광주공항 데이터 전처리
# * 현재 상황
#     - 결측치 제거 필요
#     - 항공 스케줄 데이터가 연도별, 월별로 나뉘어 있음 => 데이터 병합 필요

# %%
# 2017년 광주공항 데이터
import pandas as pd

Jan_17 = pd.read_csv("C:/Data/schedule/2017/광주/2017_1.csv", encoding = 'cp949')
Feb_17 = pd.read_csv("C:/Data/schedule/2017/광주/2017_2.csv", encoding = 'cp949')
Mar_17 = pd.read_csv("C:/Data/schedule/2017/광주/2017_3.csv", encoding = 'cp949')
Apr_17 = pd.read_csv("C:/Data/schedule/2017/광주/2017_4.csv", encoding = 'cp949')
May_17 = pd.read_csv("C:/Data/schedule/2017/광주/2017_5.csv", encoding = 'cp949')
Jun_17 = pd.read_csv("C:/Data/schedule/2017/광주/2017_6.csv", encoding = 'cp949')
Jul_17 = pd.read_csv("C:/Data/schedule/2017/광주/2017_7.csv", encoding = 'cp949')
Aug_17 = pd.read_csv("C:/Data/schedule/2017/광주/2017_8.csv", encoding = 'cp949')
Sep_17 = pd.read_csv("C:/Data/schedule/2017/광주/2017_9.csv", encoding = 'cp949')
Oct_17 = pd.read_csv("C:/Data/schedule/2017/광주/2017_10.csv", encoding = 'cp949')
Nov_17 = pd.read_csv("C:/Data/schedule/2017/광주/2017_11.csv", encoding = 'cp949')
Dec_17 = pd.read_csv("C:/Data/schedule/2017/광주/2017_12.csv", encoding = 'cp949')
Jan
# Out:
#              일자   항공사      편명                도착     계획     예상     출발  구분  현황
# 0    2017-01-31  대한항공  KE1902  제주(CJU)->광주(KWJ)   8:35   8:35   8:50  여객  출발
# 2    2017-01-31  대한항공  KE1904  제주(CJU)->광주(KWJ)  11:45  11:45  12:02  여객  출발
# 4    2017-01-31  대한항공  KE1906  제주(CJU)->광주(KWJ)  15:00  15:00  15:15  여객  출발
# 6    2017-01-31  대한항공  KE1900  제주(CJU)->광주(KWJ)  16:00  17:00  16:56  여객  지연
# 8    2017-01-31  대한항공  KE1908  제주(CJU)->광주(KWJ)  18:05  18:05  18:22  여객  출발
# ..          ...   ...     ...               ...    ...    ...    ...  ..  ..
# 326  2017-01-01  대한항공  KE1902  제주(CJU)->광주(KWJ)   8:35   8:35   8:51  여객  출발
# 328  2017-01-01  대한항공  KE1904  제주(CJU)->광주(KWJ)  11:45  11:45  12:03  여객  출발
# 330  2017-01-01  대한항공  KE1906  제주(CJU)->광주(KWJ)  15:00  15:35  15:32  여객  지연
# 332  2017-01-01  대한항공  KE1900  제주(CJU)->광주(KWJ)  16:00  16:00  16:27  여객  출발
# 334  2017-01-01  대한항공  KE1908  제주(CJU)->광주(KWJ)  18:05  18:05  18:25  여객  출발
#
# [168 rows x 9 columns]

# %%
# 공백1, 공백2 열 삭제
Jan_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Feb_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Mar_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Apr_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
May_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jun_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jul_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Aug_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Sep_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Oct_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Nov_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Dec_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jan_17
# Out:
#              일자   항공사      편명                도착     계획     예상     출발   구분   현황
# 0    2017-01-31  대한항공  KE1902  제주(CJU)->광주(KWJ)   8:35   8:35   8:50   여객   출발
# 1           NaN   NaN     NaN               NaN    NaN    NaN    NaN  NaN  NaN
# 2    2017-01-31  대한항공  KE1904  제주(CJU)->광주(KWJ)  11:45  11:45  12:02   여객   출발
# 3           NaN   NaN     NaN               NaN    NaN    NaN    NaN  NaN  NaN
# 4    2017-01-31  대한항공  KE1906  제주(CJU)->광주(KWJ)  15:00  15:00  15:15   여객   출발
# ..          ...   ...     ...               ...    ...    ...    ...  ...  ...
# 330  2017-01-01  대한항공  KE1906  제주(CJU)->광주(KWJ)  15:00  15:35  15:32   여객   지연
# 331         NaN   NaN     NaN               NaN    NaN    NaN    NaN  NaN  NaN
# 332  2017-01-01  대한항공  KE1900  제주(CJU)->광주(KWJ)  16:00  16:00  16:27   여객   출발
# 333         NaN   NaN     NaN               NaN    NaN    NaN    NaN  NaN  NaN
# 334  2017-01-01  대한항공  KE1908  제주(CJU)->광주(KWJ)  18:05  18:05  18:25   여객   출발
#
# [335 rows x 9 columns]

# %%
# 홀수행만 필터링(짝수행에는 빈값이 들어있음)
Jan_17 = Jan_17.iloc[::2, :]
Feb_17 = Feb_17.iloc[::2, :]
Mar_17 = Mar_17.iloc[::2, :]
Apr_17 = Apr_17.iloc[::2, :]
May_17 = May_17.iloc[::2, :]
Jun_17 = Jun_17.iloc[::2, :]
Jul_17 = Jul_17.iloc[::2, :]
Aug_17 = Aug_17.iloc[::2, :]
Sep_17 = Sep_17.iloc[::2, :]
Oct_17 = Oct_17.iloc[::2, :]
Nov_17 = Nov_17.iloc[::2, :]
Dec_17 = Dec_17.iloc[::2, :]
Jan_17
# Out:
#              일자   항공사      편명                도착     계획     예상     출발  구분  현황
# 0    2017-01-31  대한항공  KE1902  제주(CJU)->광주(KWJ)   8:35   8:35   8:50  여객  출발
# 2    2017-01-31  대한항공  KE1904  제주(CJU)->광주(KWJ)  11:45  11:45  12:02  여객  출발
# 4    2017-01-31  대한항공  KE1906  제주(CJU)->광주(KWJ)  15:00  15:00  15:15  여객  출발
# 6    2017-01-31  대한항공  KE1900  제주(CJU)->광주(KWJ)  16:00  17:00  16:56  여객  지연
# 8    2017-01-31  대한항공  KE1908  제주(CJU)->광주(KWJ)  18:05  18:05  18:22  여객  출발
# ..          ...   ...     ...               ...    ...    ...    ...  ..  ..
# 326  2017-01-01  대한항공  KE1902  제주(CJU)->광주(KWJ)   8:35   8:35   8:51  여객  출발
# 328  2017-01-01  대한항공  KE1904  제주(CJU)->광주(KWJ)  11:45  11:45  12:03  여객  출발
# 330  2017-01-01  대한항공  KE1906  제주(CJU)->광주(KWJ)  15:00  15:35  15:32  여객  지연
# 332  2017-01-01  대한항공  KE1900  제주(CJU)->광주(KWJ)  16:00  16:00  16:27  여객  출발
# 334  2017-01-01  대한항공  KE1908  제주(CJU)->광주(KWJ)  18:05  18:05  18:25  여객  출발
#
# [168 rows x 9 columns]

# %%
# 데이터 병합
kwj_17 = pd.concat([Jan_17, Feb_17, Mar_17, Apr_17, May_17, Jun_17, Jul_17, Aug_17, Sep_17, Oct_17, Nov_17, Dec_17])
# 마지막으로 결측값 제거
kwj_17.dropna(how='all')
# Out:
#              일자   항공사      편명                도착     계획     예상     출발  구분  현황
# 0    2017-01-31  대한항공  KE1902  제주(CJU)->광주(KWJ)   8:35   8:35   8:50  여객  출발
# 2    2017-01-31  대한항공  KE1904  제주(CJU)->광주(KWJ)  11:45  11:45  12:02  여객  출발
# 4    2017-01-31  대한항공  KE1906  제주(CJU)->광주(KWJ)  15:00  15:00  15:15  여객  출발
# 6    2017-01-31  대한항공  KE1900  제주(CJU)->광주(KWJ)  16:00  17:00  16:56  여객  지연
# 8    2017-01-31  대한항공  KE1908  제주(CJU)->광주(KWJ)  18:05  18:05  18:22  여객  출발
# ..          ...   ...     ...               ...    ...    ...    ...  ..  ..
# 300  2017-12-01  대한항공  KE1902  제주(CJU)->광주(KWJ)   8:35   8:35   8:49  여객  출발
# 302  2017-12-01  대한항공  KE1904  제주(CJU)->광주(KWJ)  11:45  11:45  11:54  여객  출발
# 304  2017-12-01  대한항공  KE1906  제주(CJU)->광주(KWJ)  15:00  15:00  15:11  여객  출발
# 306  2017-12-01  대한항공  KE1900  제주(CJU)->광주(KWJ)  16:05  16:05  16:20  여객  출발
# 308  2017-12-01  대한항공  KE1908  제주(CJU)->광주(KWJ)  18:10  18:10  19:01  여객  지연
#
# [1809 rows x 9 columns]

# %%
# 2018년 광주공항 데이터 
import pandas as pd

Jan_18 = pd.read_csv("C:/Data/schedule/2018/광주/2018_1.csv", encoding = 'cp949')
Feb_18 = pd.read_csv("C:/Data/schedule/2018/광주/2018_2.csv", encoding = 'cp949')
Mar_18 = pd.read_csv("C:/Data/schedule/2018/광주/2018_3.csv", encoding = 'cp949')
Apr_18 = pd.read_csv("C:/Data/schedule/2018/광주/2018_4.csv", encoding = 'cp949')
May_18 = pd.read_csv("C:/Data/schedule/2018/광주/2018_5.csv", encoding = 'cp949')
Jun_18 = pd.read_csv("C:/Data/schedule/2018/광주/2018_6.csv", encoding = 'cp949')
Jul_18 = pd.read_csv("C:/Data/schedule/2018/광주/2018_7.csv", encoding = 'cp949')
Aug_18 = pd.read_csv("C:/Data/schedule/2018/광주/2018_8.csv", encoding = 'cp949')
Sep_18 = pd.read_csv("C:/Data/schedule/2018/광주/2018_9.csv", encoding = 'cp949')
Oct_18 = pd.read_csv("C:/Data/schedule/2018/광주/2018_10.csv", encoding = 'cp949')
Nov_18 = pd.read_csv("C:/Data/schedule/2018/광주/2018_11.csv", encoding = 'cp949')
Dec_18 = pd.read_csv("C:/Data/schedule/2018/광주/2018_12.csv", encoding = 'cp949')

# 공백1, 공백2 열 삭제
Jan_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Feb_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Mar_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Apr_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
May_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jun_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jul_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Aug_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Sep_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Oct_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Nov_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Dec_18.drop(['공백1', '공백2'], axis = 1, inplace = True)

# 홀수행만 필터링(짝수행에는 빈값이 들어있음)
Jan_18 = Jan_18.iloc[::2, :]
Feb_18 = Feb_18.iloc[::2, :]
Mar_18 = Mar_18.iloc[::2, :]
Apr_18 = Apr_18.iloc[::2, :]
May_18 = May_18.iloc[::2, :]
Jun_18 = Jun_18.iloc[::2, :]
Jul_18 = Jul_18.iloc[::2, :]
Aug_18 = Aug_18.iloc[::2, :]
Sep_18 = Sep_18.iloc[::2, :]
Oct_18 = Oct_18.iloc[::2, :]
Nov_18 = Nov_18.iloc[::2, :]
Dec_18 = Dec_18.iloc[::2, :]

# 데이터 병합
kwj_18 = pd.concat([Jan_18, Feb_18, Mar_18, Apr_18, May_18, Jun_18, Jul_18, Aug_18, Sep_18, Oct_18, Nov_18, Dec_18])
# 마지막으로 결측값 제거
kwj_18.dropna(how='all')
# Out:
#              일자   항공사      편명                도착     계획     예상     출발  구분  현황
# 0    2018-01-31  대한항공  KE1902  제주(CJU)->광주(KWJ)  08:35  08:35  08:56  여객  출발
# 2    2018-01-31  대한항공  KE1904  제주(CJU)->광주(KWJ)  11:45  11:45  12:15  여객  지연
# 4    2018-01-31  대한항공  KE1906  제주(CJU)->광주(KWJ)  15:00  15:00  15:50  여객  지연
# 6    2018-01-31  대한항공  KE1900  제주(CJU)->광주(KWJ)  16:00  16:00  16:24  여객  출발
# 8    2018-01-31  대한항공  KE1908  제주(CJU)->광주(KWJ)  18:10  18:10  18:37  여객  출발
# ..          ...   ...     ...               ...    ...    ...    ...  ..  ..
# 316  2018-12-01  대한항공  KE1902  제주(CJU)->광주(KWJ)  08:35  08:35  08:50  여객  출발
# 318  2018-12-01  대한항공  KE1904  제주(CJU)->광주(KWJ)  11:45  11:45  12:00  여객  출발
# 320  2018-12-01  대한항공  KE1906  제주(CJU)->광주(KWJ)  15:05  15:05  15:20  여객  출발
# 322  2018-12-01  대한항공  KE1900  제주(CJU)->광주(KWJ)  16:10  16:10  16:31  여객  출발
# 324  2018-12-01  대한항공  KE1908  제주(CJU)->광주(KWJ)  18:10  18:10  18:38  여객  출발
#
# [1985 rows x 9 columns]

# %%
# 2019년 광주공항 데이터 
import pandas as pd

Jan_19 = pd.read_csv("C:/Data/schedule/2019/광주/2019_1.csv", encoding = 'cp949')
Feb_19 = pd.read_csv("C:/Data/schedule/2019/광주/2019_2.csv", encoding = 'cp949')
Mar_19 = pd.read_csv("C:/Data/schedule/2019/광주/2019_3.csv", encoding = 'cp949')
Apr_19 = pd.read_csv("C:/Data/schedule/2019/광주/2019_4.csv", encoding = 'cp949')
May_19 = pd.read_csv("C:/Data/schedule/2019/광주/2019_5.csv", encoding = 'cp949')
Jun_19 = pd.read_csv("C:/Data/schedule/2019/광주/2019_6.csv", encoding = 'cp949')
Jul_19 = pd.read_csv("C:/Data/schedule/2019/광주/2019_7.csv", encoding = 'cp949')
Aug_19 = pd.read_csv("C:/Data/schedule/2019/광주/2019_8.csv", encoding = 'cp949')
Sep_19 = pd.read_csv("C:/Data/schedule/2019/광주/2019_9.csv", encoding = 'cp949')
Oct_19 = pd.read_csv("C:/Data/schedule/2019/광주/2019_10.csv", encoding = 'cp949')
Nov_19 = pd.read_csv("C:/Data/schedule/2019/광주/2019_11.csv", encoding = 'cp949')
Dec_19 = pd.read_csv("C:/Data/schedule/2019/광주/2019_12.csv", encoding = 'cp949')

# 공백1, 공백2 열 삭제
Jan_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Feb_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Mar_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Apr_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
May_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jun_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jul_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Aug_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Sep_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Oct_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Nov_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Dec_19.drop(['공백1', '공백2'], axis = 1, inplace = True)

# 홀수행만 필터링(짝수행에는 빈값이 들어있음)
Jan_19 = Jan_19.iloc[::2, :]
Feb_19 = Feb_19.iloc[::2, :]
Mar_19 = Mar_19.iloc[::2, :]
Apr_19 = Apr_19.iloc[::2, :]
May_19 = May_19.iloc[::2, :]
Jun_19 = Jun_19.iloc[::2, :]
Jul_19 = Jul_19.iloc[::2, :]
Aug_19 = Aug_19.iloc[::2, :]
Sep_19 = Sep_19.iloc[::2, :]
Oct_19 = Oct_19.iloc[::2, :]
Nov_19 = Nov_19.iloc[::2, :]
Dec_19 = Dec_19.iloc[::2, :]

# 데이터 병합
kwj_19 = pd.concat([Jan_19, Feb_19, Mar_19, Apr_19, May_19, Jun_19, Jul_19, Aug_19, Sep_19, Oct_19, Nov_19, Dec_19])
# 마지막으로 결측값 제거
kwj_19.dropna(how='all')
# Out:
#              일자   항공사      편명                도착     계획     예상     출발   구분   현황
# 0    2019-01-31  대한항공  KE1902  제주(CJU)->광주(KWJ)  08:35     여객     결항  NaN  NaN
# 2    2019-01-31  대한항공  KE1904  제주(CJU)->광주(KWJ)  11:45  11:45  12:07   여객   출발
# 4    2019-01-31  대한항공  KE1906  제주(CJU)->광주(KWJ)  15:05  15:05  15:25   여객   출발
# 6    2019-01-31  대한항공  KE1900  제주(CJU)->광주(KWJ)  16:10  16:10  16:34   여객   출발
# 8    2019-01-31  대한항공  KE1908  제주(CJU)->광주(KWJ)  18:10  18:10  18:32   여객   출발
# ..          ...   ...     ...               ...    ...    ...    ...  ...  ...
# 266  2019-12-01  대한항공  KE1908  제주(CJU)->광주(KWJ)  17:50  17:50  18:20   여객   지연
# 268  2019-12-01  대한항공  KE1902  제주(CJU)->광주(KWJ)  08:45  08:45  09:05   여객   출발
# 270  2019-12-01  대한항공  KE1904  제주(CJU)->광주(KWJ)  11:30  11:30  11:58   여객   출발
# 272  2019-12-01  대한항공  KE1906  제주(CJU)->광주(KWJ)  15:05  15:05  15:26   여객   출발
# 274  2019-12-01  대한항공  KE1908  제주(CJU)->광주(KWJ)  17:50  17:50  18:20   여객   지연
#
# [1734 rows x 9 columns]

# %%
# 2020년 광주공항 데이터 
import pandas as pd

Jan_20 = pd.read_csv("C:/Data/schedule/2020/광주/2020_1.csv", encoding = 'cp949')
Feb_20 = pd.read_csv("C:/Data/schedule/2020/광주/2020_2.csv", encoding = 'cp949')
Mar_20 = pd.read_csv("C:/Data/schedule/2020/광주/2020_3.csv", encoding = 'cp949')
Apr_20 = pd.read_csv("C:/Data/schedule/2020/광주/2020_4.csv", encoding = 'cp949')
May_20 = pd.read_csv("C:/Data/schedule/2020/광주/2020_5.csv", encoding = 'cp949')
Jun_20 = pd.read_csv("C:/Data/schedule/2020/광주/2020_6.csv", encoding = 'cp949')
Jul_20 = pd.read_csv("C:/Data/schedule/2020/광주/2020_7.csv", encoding = 'cp949')
Aug_20 = pd.read_csv("C:/Data/schedule/2020/광주/2020_8.csv", encoding = 'cp949')
Sep_20 = pd.read_csv("C:/Data/schedule/2020/광주/2020_9.csv", encoding = 'cp949')
Oct_20 = pd.read_csv("C:/Data/schedule/2020/광주/2020_10.csv", encoding = 'cp949')
Nov_20 = pd.read_csv("C:/Data/schedule/2020/광주/2020_11.csv", encoding = 'cp949')
Dec_20 = pd.read_csv("C:/Data/schedule/2020/광주/2020_12.csv", encoding = 'cp949')

# 공백1, 공백2 열 삭제
Jan_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Feb_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Mar_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Apr_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
May_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jun_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jul_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Aug_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Sep_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Oct_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Nov_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Dec_20.drop(['공백1', '공백2'], axis = 1, inplace = True)

# 홀수행만 필터링(짝수행에는 빈값이 들어있음)
Jan_20 = Jan_20.iloc[::2, :]
Feb_20 = Feb_20.iloc[::2, :]
Mar_20 = Mar_20.iloc[::2, :]
Apr_20 = Apr_20.iloc[::2, :]
May_20 = May_20.iloc[::2, :]
Jun_20 = Jun_20.iloc[::2, :]
Jul_20 = Jul_20.iloc[::2, :]
Aug_20 = Aug_20.iloc[::2, :]
Sep_20 = Sep_20.iloc[::2, :]
Oct_20 = Oct_20.iloc[::2, :]
Nov_20 = Nov_20.iloc[::2, :]
Dec_20 = Dec_20.iloc[::2, :]

# 데이터 병합
kwj_20 = pd.concat([Jan_20, Feb_20, Mar_20, Apr_20, May_20, Jun_20, Jul_20, Aug_20, Sep_20, Oct_20, Nov_20, Dec_20])
# 마지막으로 결측값 제거
kwj_20.dropna(how='all')
# Out:
#              일자   항공사      편명                도착     계획     예상     출발  구분  현황
# 0    2020-01-31  대한항공  KE1902  제주(CJU)->광주(KWJ)  08:45  08:45  08:59  여객  출발
# 2    2020-01-31  대한항공  KE1904  제주(CJU)->광주(KWJ)  11:30  11:30  11:53  여객  출발
# 4    2020-01-31  대한항공  KE1906  제주(CJU)->광주(KWJ)  15:05  15:05  15:18  여객  출발
# 6    2020-01-31  대한항공  KE1908  제주(CJU)->광주(KWJ)  17:50  17:50  18:05  여객  출발
# 8    2020-01-30  대한항공  KE1902  제주(CJU)->광주(KWJ)  08:45  08:45  09:02  여객  출발
# ..          ...   ...     ...               ...    ...    ...    ...  ..  ..
# 110  2020-12-03  대한항공  KE1906  제주(CJU)->광주(KWJ)  15:30  15:30  15:50  여객  출발
# 112  2020-12-02  대한항공  KE1902  제주(CJU)->광주(KWJ)  07:55  07:55  08:09  여객  출발
# 114  2020-12-02  대한항공  KE1906  제주(CJU)->광주(KWJ)  15:30  15:30  15:41  여객  출발
# 116  2020-12-01  대한항공  KE1902  제주(CJU)->광주(KWJ)  07:55  07:55  08:10  여객  출발
# 118  2020-12-01  대한항공  KE1906  제주(CJU)->광주(KWJ)  15:30  15:30  15:46  여객  출발
#
# [908 rows x 9 columns]

# %%
# 2021년 광주공항 데이터 
import pandas as pd

Jan_21 = pd.read_csv("C:/Data/schedule/2021/광주/2021_1.csv", encoding = 'cp949')
Feb_21 = pd.read_csv("C:/Data/schedule/2021/광주/2021_2.csv", encoding = 'cp949')
Mar_21 = pd.read_csv("C:/Data/schedule/2021/광주/2021_3.csv", encoding = 'cp949')
Apr_21 = pd.read_csv("C:/Data/schedule/2021/광주/2021_4.csv", encoding = 'cp949')
May_21 = pd.read_csv("C:/Data/schedule/2021/광주/2021_5.csv", encoding = 'cp949')
Jun_21 = pd.read_csv("C:/Data/schedule/2021/광주/2021_6.csv", encoding = 'cp949')
Jul_21 = pd.read_csv("C:/Data/schedule/2021/광주/2021_7.csv", encoding = 'cp949')
Aug_21 = pd.read_csv("C:/Data/schedule/2021/광주/2021_8.csv", encoding = 'cp949')
Sep_21 = pd.read_csv("C:/Data/schedule/2021/광주/2021_9.csv", encoding = 'cp949')
Oct_21 = pd.read_csv("C:/Data/schedule/2021/광주/2021_10.csv", encoding = 'cp949')
Nov_21 = pd.read_csv("C:/Data/schedule/2021/광주/2021_11.csv", encoding = 'cp949')
Dec_21 = pd.read_csv("C:/Data/schedule/2021/광주/2021_12.csv", encoding = 'cp949')

# 공백1, 공백2 열 삭제
Jan_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Feb_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Mar_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Apr_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
May_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jun_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jul_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Aug_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Sep_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Oct_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Nov_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Dec_21.drop(['공백1', '공백2'], axis = 1, inplace = True)

# 홀수행만 필터링(짝수행에는 빈값이 들어있음)
Jan_21 = Jan_21.iloc[::2, :]
Feb_21 = Feb_21.iloc[::2, :]
Mar_21 = Mar_21.iloc[::2, :]
Apr_21 = Apr_21.iloc[::2, :]
May_21 = May_21.iloc[::2, :]
Jun_21 = Jun_21.iloc[::2, :]
Jul_21 = Jul_21.iloc[::2, :]
Aug_21 = Aug_21.iloc[::2, :]
Sep_21 = Sep_21.iloc[::2, :]
Oct_21 = Oct_21.iloc[::2, :]
Nov_21 = Nov_21.iloc[::2, :]
Dec_21 = Dec_21.iloc[::2, :]

# 데이터 병합
kwj_21 = pd.concat([Jan_21, Feb_21, Mar_21, Apr_21, May_21, Jun_21, Jul_21, Aug_21, Sep_21, Oct_21, Nov_21, Dec_21])
# 마지막으로 결측값 제거
kwj_21.dropna(how='all')
# Out:
#              일자   항공사      편명                도착     계획     예상     출발  구분  현황
# 0    2021-01-31  대한항공  KE1906  제주(CJU)->광주(KWJ)  15:30  15:30  15:41  여객  출발
# 2    2021-01-30  대한항공  KE1902  제주(CJU)->광주(KWJ)  07:55  07:55  08:06  여객  출발
# 4    2021-01-29  대한항공  KE1902  제주(CJU)->광주(KWJ)  07:55  10:30  10:43  여객  지연
# 6    2021-01-28  대한항공  KE1906  제주(CJU)->광주(KWJ)  15:30  15:30  15:49  여객  출발
# 8    2021-01-27  대한항공  KE1906  제주(CJU)->광주(KWJ)  15:30  15:30  15:50  여객  출발
# ..          ...   ...     ...               ...    ...    ...    ...  ..  ..
# 114  2021-12-03  대한항공  KE1906  제주(CJU)->광주(KWJ)  18:20  18:20  18:38  여객  출발
# 116  2021-12-02  대한항공  KE1902  제주(CJU)->광주(KWJ)  07:25  07:25  07:38  여객  출발
# 118  2021-12-02  대한항공  KE1906  제주(CJU)->광주(KWJ)  18:20  18:20  18:43  여객  출발
# 120  2021-12-01  대한항공  KE1902  제주(CJU)->광주(KWJ)  07:25  07:25  07:32  여객  출발
# 122  2021-12-01  대한항공  KE1906  제주(CJU)->광주(KWJ)  18:20  18:20  18:43  여객  출발
#
# [699 rows x 9 columns]

# %%
# 광주공항 2017 ~ 2021년도 데이터 병합
kwj = pd.concat([kwj_17, kwj_18, kwj_19, kwj_20, kwj_21])
kwj
# Out:
#              일자   항공사      편명                도착     계획     예상     출발  구분  현황
# 0    2017-01-31  대한항공  KE1902  제주(CJU)->광주(KWJ)   8:35   8:35   8:50  여객  출발
# 2    2017-01-31  대한항공  KE1904  제주(CJU)->광주(KWJ)  11:45  11:45  12:02  여객  출발
# 4    2017-01-31  대한항공  KE1906  제주(CJU)->광주(KWJ)  15:00  15:00  15:15  여객  출발
# 6    2017-01-31  대한항공  KE1900  제주(CJU)->광주(KWJ)  16:00  17:00  16:56  여객  지연
# 8    2017-01-31  대한항공  KE1908  제주(CJU)->광주(KWJ)  18:05  18:05  18:22  여객  출발
# ..          ...   ...     ...               ...    ...    ...    ...  ..  ..
# 114  2021-12-03  대한항공  KE1906  제주(CJU)->광주(KWJ)  18:20  18:20  18:38  여객  출발
# 116  2021-12-02  대한항공  KE1902  제주(CJU)->광주(KWJ)  07:25  07:25  07:38  여객  출발
# 118  2021-12-02  대한항공  KE1906  제주(CJU)->광주(KWJ)  18:20  18:20  18:43  여객  출발
# 120  2021-12-01  대한항공  KE1902  제주(CJU)->광주(KWJ)  07:25  07:25  07:32  여객  출발
# 122  2021-12-01  대한항공  KE1906  제주(CJU)->광주(KWJ)  18:20  18:20  18:43  여객  출발
#
# [7217 rows x 9 columns]

# %% [markdown]
# ### 김포공항 데이터 전처리
# * 현재 상황
#     - 결측치 제거 필요
#     - 항공 스케줄 데이터가 연도별, 월별로 나뉘어 있음 => 데이터 병합 필요

# %%
# 2017년 김포공항 데이터 
import pandas as pd

Jan_17 = pd.read_csv("C:/Data/schedule/2017/김포/2017_1.csv", encoding = 'cp949')
Feb_17 = pd.read_csv("C:/Data/schedule/2017/김포/2017_2.csv", encoding = 'cp949')
Mar_17 = pd.read_csv("C:/Data/schedule/2017/김포/2017_3.csv", encoding = 'cp949')
Apr_17 = pd.read_csv("C:/Data/schedule/2017/김포/2017_4.csv", encoding = 'cp949')
May_17 = pd.read_csv("C:/Data/schedule/2017/김포/2017_5.csv", encoding = 'cp949')
Jun_17 = pd.read_csv("C:/Data/schedule/2017/김포/2017_6.csv", encoding = 'cp949')
Jul_17 = pd.read_csv("C:/Data/schedule/2017/김포/2017_7.csv", encoding = 'cp949')
Aug_17 = pd.read_csv("C:/Data/schedule/2017/김포/2017_8.csv", encoding = 'cp949')
Sep_17 = pd.read_csv("C:/Data/schedule/2017/김포/2017_9.csv", encoding = 'cp949')
Oct_17 = pd.read_csv("C:/Data/schedule/2017/김포/2017_10.csv", encoding = 'cp949')
Nov_17 = pd.read_csv("C:/Data/schedule/2017/김포/2017_11.csv", encoding = 'cp949')
Dec_17 = pd.read_csv("C:/Data/schedule/2017/김포/2017_12.csv", encoding = 'cp949')

# 공백1, 공백2 열 삭제
Jan_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Feb_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Mar_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Apr_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
May_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jun_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jul_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Aug_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Sep_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Oct_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Nov_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Dec_17.drop(['공백1', '공백2'], axis = 1, inplace = True)

# 홀수행만 필터링(짝수행에는 빈값이 들어있음)
Jan_17 = Jan_17.iloc[::2, :]
Feb_17 = Feb_17.iloc[::2, :]
Mar_17 = Mar_17.iloc[::2, :]
Apr_17 = Apr_17.iloc[::2, :]
May_17 = May_17.iloc[::2, :]
Jun_17 = Jun_17.iloc[::2, :]
Jul_17 = Jul_17.iloc[::2, :]
Aug_17 = Aug_17.iloc[::2, :]
Sep_17 = Sep_17.iloc[::2, :]
Oct_17 = Oct_17.iloc[::2, :]
Nov_17 = Nov_17.iloc[::2, :]
Dec_17 = Dec_17.iloc[::2, :]

# 데이터 병합
gmp_17 = pd.concat([Jan_17, Feb_17, Mar_17, Apr_17, May_17, Jun_17, Jul_17, Aug_17, Sep_17, Oct_17, Nov_17, Dec_17])
# 마지막으로 결측값 제거
gmp_17.dropna(how='all')
# Out:
#               일자   항공사      편명                도착     계획     예상     출발  구분  현황
# 0     2017-01-31  대한항공  KE1200  제주(CJU)->김포(GMP)   6:55   6:55   7:12  여객  출발
# 2     2017-01-31  대한항공  KE1250  제주(CJU)->김포(GMP)   7:10   7:10   7:27  여객  출발
# 4     2017-01-31  대한항공  KE1204  제주(CJU)->김포(GMP)  10:25  10:25  10:45  여객  출발
# 6     2017-01-31  대한항공  KE1210  제주(CJU)->김포(GMP)  11:10  11:10  11:26  여객  출발
# 8     2017-01-31  대한항공  KE1212  제주(CJU)->김포(GMP)  11:40  11:40  11:56  여객  출발
# ...          ...   ...     ...               ...    ...    ...    ...  ..  ..
# 1490  2017-12-01  대한항공  KE1238  제주(CJU)->김포(GMP)  19:30  19:30  19:51  여객  출발
# 1492  2017-12-01  대한항공  KE1240  제주(CJU)->김포(GMP)  20:10  20:10  20:33  여객  출발
# 1494  2017-12-01  대한항공  KE1242  제주(CJU)->김포(GMP)  20:45  20:45  21:05  여객  출발
# 1496  2017-12-01  대한항공  KE1244  제주(CJU)->김포(GMP)  20:55  20:55  21:13  여객  출발
# 1498  2017-12-01  대한항공  KE1246  제주(CJU)->김포(GMP)  21:05  21:40  22:00  여객  지연
#
# [9777 rows x 9 columns]

# %%
# 2018년 김포공항 데이터 
import pandas as pd

Jan_18 = pd.read_csv("C:/Data/schedule/2018/김포/2018_1.csv", encoding = 'cp949')
Feb_18 = pd.read_csv("C:/Data/schedule/2018/김포/2018_2.csv", encoding = 'cp949')
Mar_18 = pd.read_csv("C:/Data/schedule/2018/김포/2018_3.csv", encoding = 'cp949')
Apr_18 = pd.read_csv("C:/Data/schedule/2018/김포/2018_4.csv", encoding = 'cp949')
May_18 = pd.read_csv("C:/Data/schedule/2018/김포/2018_5.csv", encoding = 'cp949')
Jun_18 = pd.read_csv("C:/Data/schedule/2018/김포/2018_6.csv", encoding = 'cp949')
Jul_18 = pd.read_csv("C:/Data/schedule/2018/김포/2018_7.csv", encoding = 'cp949')
Aug_18 = pd.read_csv("C:/Data/schedule/2018/김포/2018_8.csv", encoding = 'cp949')
Sep_18 = pd.read_csv("C:/Data/schedule/2018/김포/2018_9.csv", encoding = 'cp949')
Oct_18 = pd.read_csv("C:/Data/schedule/2018/김포/2018_10.csv", encoding = 'cp949')
Nov_18 = pd.read_csv("C:/Data/schedule/2018/김포/2018_11.csv", encoding = 'cp949')
Dec_18 = pd.read_csv("C:/Data/schedule/2018/김포/2018_12.csv", encoding = 'cp949')

# 공백1, 공백2 열 삭제
Jan_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Feb_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Mar_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Apr_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
May_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jun_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jul_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Aug_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Sep_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Oct_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Nov_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Dec_18.drop(['공백1', '공백2'], axis = 1, inplace = True)

# 홀수행만 필터링(짝수행에는 빈값이 들어있음)
Jan_18 = Jan_18.iloc[::2, :]
Feb_18 = Feb_18.iloc[::2, :]
Mar_18 = Mar_18.iloc[::2, :]
Apr_18 = Apr_18.iloc[::2, :]
May_18 = May_18.iloc[::2, :]
Jun_18 = Jun_18.iloc[::2, :]
Jul_18 = Jul_18.iloc[::2, :]
Aug_18 = Aug_18.iloc[::2, :]
Sep_18 = Sep_18.iloc[::2, :]
Oct_18 = Oct_18.iloc[::2, :]
Nov_18 = Nov_18.iloc[::2, :]
Dec_18 = Dec_18.iloc[::2, :]

# 데이터 병합
gmp_18 = pd.concat([Jan_18, Feb_18, Mar_18, Apr_18, May_18, Jun_18, Jul_18, Aug_18, Sep_18, Oct_18, Nov_18, Dec_18])
# 마지막으로 결측값 제거
gmp_18.dropna(how='all')
# Out:
#               일자   항공사      편명                도착     계획     예상     출발  구분   현황
# 0     2018-01-31  대한항공  KE1200  제주(CJU)->김포(GMP)  06:45  06:45  06:54  여객   출발
# 2     2018-01-31  대한항공  KE1250  제주(CJU)->김포(GMP)  07:00  07:00  07:10  여객   출발
# 4     2018-01-31  대한항공  KE1202  제주(CJU)->김포(GMP)  07:50  08:12     여객  출발  NaN
# 6     2018-01-31  대한항공  KE1204  제주(CJU)->김포(GMP)  10:25  10:25  10:38  여객   출발
# 8     2018-01-31  대한항공  KE1210  제주(CJU)->김포(GMP)  11:10  11:10  11:22  여객   출발
# ...          ...   ...     ...               ...    ...    ...    ...  ..  ...
# 1502  2018-12-01  대한항공  KE1230  제주(CJU)->김포(GMP)  19:00  19:00  19:21  여객   출발
# 1504  2018-12-01  대한항공  KE1232  제주(CJU)->김포(GMP)  19:30  19:30  19:44  여객   출발
# 1506  2018-12-01  대한항공  KE1234  제주(CJU)->김포(GMP)  20:10  20:10  20:35  여객   출발
# 1508  2018-12-01  대한항공  KE1238  제주(CJU)->김포(GMP)  20:55  20:55  21:15  여객   출발
# 1510  2018-12-01  대한항공  KE1240  제주(CJU)->김포(GMP)  21:05  21:05  21:27  여객   출발
#
# [9543 rows x 9 columns]

# %%
# 2019년 김포공항 데이터 
import pandas as pd

Jan_19 = pd.read_csv("C:/Data/schedule/2019/김포/2019_1.csv", encoding = 'cp949')
Feb_19 = pd.read_csv("C:/Data/schedule/2019/김포/2019_2.csv", encoding = 'cp949')
Mar_19 = pd.read_csv("C:/Data/schedule/2019/김포/2019_3.csv", encoding = 'cp949')
Apr_19 = pd.read_csv("C:/Data/schedule/2019/김포/2019_4.csv", encoding = 'cp949')
May_19 = pd.read_csv("C:/Data/schedule/2019/김포/2019_5.csv", encoding = 'cp949')
Jun_19 = pd.read_csv("C:/Data/schedule/2019/김포/2019_6.csv", encoding = 'cp949')
Jul_19 = pd.read_csv("C:/Data/schedule/2019/김포/2019_7.csv", encoding = 'cp949')
Aug_19 = pd.read_csv("C:/Data/schedule/2019/김포/2019_8.csv", encoding = 'cp949')
Sep_19 = pd.read_csv("C:/Data/schedule/2019/김포/2019_9.csv", encoding = 'cp949')
Oct_19 = pd.read_csv("C:/Data/schedule/2019/김포/2019_10.csv", encoding = 'cp949')
Nov_19 = pd.read_csv("C:/Data/schedule/2019/김포/2019_11.csv", encoding = 'cp949')
Dec_19 = pd.read_csv("C:/Data/schedule/2019/김포/2019_12.csv", encoding = 'cp949')

# 공백1, 공백2 열 삭제
Jan_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Feb_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Mar_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Apr_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
May_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jun_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jul_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Aug_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Sep_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Oct_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Nov_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Dec_19.drop(['공백1', '공백2'], axis = 1, inplace = True)

# 홀수행만 필터링(짝수행에는 빈값이 들어있음)
Jan_19 = Jan_19.iloc[::2, :]
Feb_19 = Feb_19.iloc[::2, :]
Mar_19 = Mar_19.iloc[::2, :]
Apr_19 = Apr_19.iloc[::2, :]
May_19 = May_19.iloc[::2, :]
Jun_19 = Jun_19.iloc[::2, :]
Jul_19 = Jul_19.iloc[::2, :]
Aug_19 = Aug_19.iloc[::2, :]
Sep_19 = Sep_19.iloc[::2, :]
Oct_19 = Oct_19.iloc[::2, :]
Nov_19 = Nov_19.iloc[::2, :]
Dec_19 = Dec_19.iloc[::2, :]

# 데이터 병합
gmp_19 = pd.concat([Jan_19, Feb_19, Mar_19, Apr_19, May_19, Jun_19, Jul_19, Aug_19, Sep_19, Oct_19, Nov_19, Dec_19])
# 마지막으로 결측값 제거
gmp_19.dropna(how='all')
# Out:
#               일자   항공사      편명                도착     계획     예상     출발  구분  현황
# 0     2019-01-31  대한항공  KE1200  제주(CJU)->김포(GMP)  06:45  06:45  06:55  여객  출발
# 2     2019-01-31  대한항공  KE1202  제주(CJU)->김포(GMP)  07:00  07:00  07:12  여객  출발
# 4     2019-01-31  대한항공  KE1206  제주(CJU)->김포(GMP)  10:25  10:25  10:45  여객  출발
# 6     2019-01-31  대한항공  KE1208  제주(CJU)->김포(GMP)  11:10  11:10  11:39  여객  출발
# 8     2019-01-31  대한항공  KE1250  제주(CJU)->김포(GMP)  11:40  11:40  12:16  여객  지연
# ...          ...   ...     ...               ...    ...    ...    ...  ..  ..
# 1606  2019-12-01  대한항공  KE1238  제주(CJU)->김포(GMP)  19:30  19:30  19:45  여객  출발
# 1608  2019-12-01  대한항공  KE1240  제주(CJU)->김포(GMP)  20:10  20:10  20:22  여객  출발
# 1610  2019-12-01  대한항공  KE1242  제주(CJU)->김포(GMP)  20:35  21:05  21:49  여객  지연
# 1612  2019-12-01  대한항공  KE1244  제주(CJU)->김포(GMP)  20:50  20:50  21:17  여객  출발
# 1614  2019-12-01  대한항공  KE1246  제주(CJU)->김포(GMP)  21:05  21:05  22:00  여객  지연
#
# [9452 rows x 9 columns]

# %%
# 2020년 김포공항 데이터 
import pandas as pd

Jan_20 = pd.read_csv("C:/Data/schedule/2020/김포/2020_1.csv", encoding = 'cp949')
Feb_20 = pd.read_csv("C:/Data/schedule/2020/김포/2020_2.csv", encoding = 'cp949')
Mar_20 = pd.read_csv("C:/Data/schedule/2020/김포/2020_3.csv", encoding = 'cp949')
Apr_20 = pd.read_csv("C:/Data/schedule/2020/김포/2020_4.csv", encoding = 'cp949')
May_20 = pd.read_csv("C:/Data/schedule/2020/김포/2020_5.csv", encoding = 'cp949')
Jun_20 = pd.read_csv("C:/Data/schedule/2020/김포/2020_6.csv", encoding = 'cp949')
Jul_20 = pd.read_csv("C:/Data/schedule/2020/김포/2020_7.csv", encoding = 'cp949')
Aug_20 = pd.read_csv("C:/Data/schedule/2020/김포/2020_8.csv", encoding = 'cp949')
Sep_20 = pd.read_csv("C:/Data/schedule/2020/김포/2020_9.csv", encoding = 'cp949')
Oct_20 = pd.read_csv("C:/Data/schedule/2020/김포/2020_10.csv", encoding = 'cp949')
Nov_20 = pd.read_csv("C:/Data/schedule/2020/김포/2020_11.csv", encoding = 'cp949')
Dec_20 = pd.read_csv("C:/Data/schedule/2020/김포/2020_12.csv", encoding = 'cp949')

# 공백1, 공백2 열 삭제
Jan_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Feb_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Mar_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Apr_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
May_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jun_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jul_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Aug_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Sep_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Oct_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Nov_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Dec_20.drop(['공백1', '공백2'], axis = 1, inplace = True)

# 홀수행만 필터링(짝수행에는 빈값이 들어있음)
Jan_20 = Jan_20.iloc[::2, :]
Feb_20 = Feb_20.iloc[::2, :]
Mar_20 = Mar_20.iloc[::2, :]
Apr_20 = Apr_20.iloc[::2, :]
May_20 = May_20.iloc[::2, :]
Jun_20 = Jun_20.iloc[::2, :]
Jul_20 = Jul_20.iloc[::2, :]
Aug_20 = Aug_20.iloc[::2, :]
Sep_20 = Sep_20.iloc[::2, :]
Oct_20 = Oct_20.iloc[::2, :]
Nov_20 = Nov_20.iloc[::2, :]
Dec_20 = Dec_20.iloc[::2, :]

# 데이터 병합
gmp_20 = pd.concat([Jan_20, Feb_20, Mar_20, Apr_20, May_20, Jun_20, Jul_20, Aug_20, Sep_20, Oct_20, Nov_20, Dec_20])
# 마지막으로 결측값 제거
gmp_20.dropna(how='all')
# Out:
#               일자   항공사      편명                도착     계획     예상     출발  구분  현황
# 0     2020-01-31  대한항공  KE1200  제주(CJU)->김포(GMP)  06:45  06:45  06:59  여객  출발
# 2     2020-01-31  대한항공  KE1202  제주(CJU)->김포(GMP)  07:00  07:00  07:09  여객  출발
# 4     2020-01-31  대한항공  KE1204  제주(CJU)->김포(GMP)  08:00  08:00  08:24  여객  출발
# 6     2020-01-31  대한항공  KE1206  제주(CJU)->김포(GMP)  10:05  10:05  10:17  여객  출발
# 8     2020-01-31  대한항공  KE1208  제주(CJU)->김포(GMP)  11:10  11:10  11:25  여객  출발
# ...          ...   ...     ...               ...    ...    ...    ...  ..  ..
# 1466  2020-12-01  대한항공  KE1278  제주(CJU)->김포(GMP)  21:15  21:15  21:31  여객  출발
# 1468  2020-12-01  대한항공  KE1272  제주(CJU)->김포(GMP)  20:30  20:30  20:47  여객  출발
# 1470  2020-12-01  대한항공  KE1274  제주(CJU)->김포(GMP)  20:50  20:50  21:03  여객  출발
# 1472  2020-12-01  대한항공  KE1276  제주(CJU)->김포(GMP)  21:00  21:00  21:12  여객  출발
# 1474  2020-12-01  대한항공  KE1278  제주(CJU)->김포(GMP)  21:15  21:15  21:31  여객  출발
#
# [8673 rows x 9 columns]

# %%
# 2021년 김포공항 데이터 
import pandas as pd

Jan_21 = pd.read_csv("C:/Data/schedule/2021/김포/2021_1.csv", encoding = 'cp949')
Feb_21 = pd.read_csv("C:/Data/schedule/2021/김포/2021_2.csv", encoding = 'cp949')
Mar_21 = pd.read_csv("C:/Data/schedule/2021/김포/2021_3.csv", encoding = 'cp949')
Apr_21 = pd.read_csv("C:/Data/schedule/2021/김포/2021_4.csv", encoding = 'cp949')
May_21 = pd.read_csv("C:/Data/schedule/2021/김포/2021_5.csv", encoding = 'cp949')
Jun_21 = pd.read_csv("C:/Data/schedule/2021/김포/2021_6.csv", encoding = 'cp949')
Jul_21 = pd.read_csv("C:/Data/schedule/2021/김포/2021_7.csv", encoding = 'cp949')
Aug_21 = pd.read_csv("C:/Data/schedule/2021/김포/2021_8.csv", encoding = 'cp949')
Sep_21 = pd.read_csv("C:/Data/schedule/2021/김포/2021_9.csv", encoding = 'cp949')
Oct_21 = pd.read_csv("C:/Data/schedule/2021/김포/2021_10.csv", encoding = 'cp949')
Nov_21 = pd.read_csv("C:/Data/schedule/2021/김포/2021_11.csv", encoding = 'cp949')
Dec_21 = pd.read_csv("C:/Data/schedule/2021/김포/2021_12.csv", encoding = 'cp949')

# 공백1, 공백2 열 삭제
Jan_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Feb_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Mar_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Apr_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
May_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jun_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jul_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Aug_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Sep_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Oct_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Nov_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Dec_21.drop(['공백1', '공백2'], axis = 1, inplace = True)

# 홀수행만 필터링(짝수행에는 빈값이 들어있음)
Jan_21 = Jan_21.iloc[::2, :]
Feb_21 = Feb_21.iloc[::2, :]
Mar_21 = Mar_21.iloc[::2, :]
Apr_21 = Apr_21.iloc[::2, :]
May_21 = May_21.iloc[::2, :]
Jun_21 = Jun_21.iloc[::2, :]
Jul_21 = Jul_21.iloc[::2, :]
Aug_21 = Aug_21.iloc[::2, :]
Sep_21 = Sep_21.iloc[::2, :]
Oct_21 = Oct_21.iloc[::2, :]
Nov_21 = Nov_21.iloc[::2, :]
Dec_21 = Dec_21.iloc[::2, :]

# 데이터 병합
gmp_21 = pd.concat([Jan_21, Feb_21, Mar_21, Apr_21, May_21, Jun_21, Jul_21, Aug_21, Sep_21, Oct_21, Nov_21, Dec_21])
# 마지막으로 결측값 제거
gmp_21.dropna(how='all')
# Out:
#               일자   항공사      편명                도착     계획     예상     출발  구분  현황
# 0     2021-01-31  대한항공  KE1210  제주(CJU)->김포(GMP)  08:50  08:50  09:05  여객  출발
# 2     2021-01-31  대한항공  KE1216  제주(CJU)->김포(GMP)  09:50  09:50  10:04  여객  출발
# 4     2021-01-31  대한항공  KE1218  제주(CJU)->김포(GMP)  10:10  10:10  10:36  여객  출발
# 6     2021-01-31  대한항공  KE1222  제주(CJU)->김포(GMP)  10:50  10:50  11:04  여객  출발
# 8     2021-01-31  대한항공  KE1224  제주(CJU)->김포(GMP)  11:20  11:20  11:39  여객  출발
# ...          ...   ...     ...               ...    ...    ...    ...  ..  ..
# 2016  2021-12-01  대한항공  KE1268  제주(CJU)->김포(GMP)  19:20  19:20  19:38  여객  출발
# 2018  2021-12-01  대한항공  KE1270  제주(CJU)->김포(GMP)  20:25  20:20  20:36  여객  출발
# 2020  2021-12-01  대한항공  KE1272  제주(CJU)->김포(GMP)  20:35  20:35  20:48  여객  출발
# 2022  2021-12-01  대한항공  KE1274  제주(CJU)->김포(GMP)  20:50  20:50  20:58  여객  출발
# 2024  2021-12-01  대한항공  KE1276  제주(CJU)->김포(GMP)  21:10  21:10  21:30  여객  출발
#
# [10937 rows x 9 columns]

# %%
# 김포공항 2017 ~ 2021년도 데이터 병합
gmp = pd.concat([gmp_17, gmp_18, gmp_19, gmp_20, gmp_21])
gmp
# Out:
#               일자   항공사      편명                도착     계획     예상     출발  구분  현황
# 0     2017-01-31  대한항공  KE1200  제주(CJU)->김포(GMP)   6:55   6:55   7:12  여객  출발
# 2     2017-01-31  대한항공  KE1250  제주(CJU)->김포(GMP)   7:10   7:10   7:27  여객  출발
# 4     2017-01-31  대한항공  KE1204  제주(CJU)->김포(GMP)  10:25  10:25  10:45  여객  출발
# 6     2017-01-31  대한항공  KE1210  제주(CJU)->김포(GMP)  11:10  11:10  11:26  여객  출발
# 8     2017-01-31  대한항공  KE1212  제주(CJU)->김포(GMP)  11:40  11:40  11:56  여객  출발
# ...          ...   ...     ...               ...    ...    ...    ...  ..  ..
# 2016  2021-12-01  대한항공  KE1268  제주(CJU)->김포(GMP)  19:20  19:20  19:38  여객  출발
# 2018  2021-12-01  대한항공  KE1270  제주(CJU)->김포(GMP)  20:25  20:20  20:36  여객  출발
# 2020  2021-12-01  대한항공  KE1272  제주(CJU)->김포(GMP)  20:35  20:35  20:48  여객  출발
# 2022  2021-12-01  대한항공  KE1274  제주(CJU)->김포(GMP)  20:50  20:50  20:58  여객  출발
# 2024  2021-12-01  대한항공  KE1276  제주(CJU)->김포(GMP)  21:10  21:10  21:30  여객  출발
#
# [48402 rows x 9 columns]

# %% [markdown]
# ### 김해공항 데이터 전처리
# * 현재 상황
#     - 결측치 제거 필요
#     - 항공 스케줄 데이터가 연도별, 월별로 나뉘어 있음 => 데이터 병합 필요

# %%
# 2017년 김해공항 데이터 
import pandas as pd

Jan_17 = pd.read_csv("C:/Data/schedule/2017/김해/2017_1.csv", encoding = 'cp949')
Feb_17 = pd.read_csv("C:/Data/schedule/2017/김해/2017_2.csv", encoding = 'cp949')
Mar_17 = pd.read_csv("C:/Data/schedule/2017/김해/2017_3.csv", encoding = 'cp949')
Apr_17 = pd.read_csv("C:/Data/schedule/2017/김해/2017_4.csv", encoding = 'cp949')
May_17 = pd.read_csv("C:/Data/schedule/2017/김해/2017_5.csv", encoding = 'cp949')
Jun_17 = pd.read_csv("C:/Data/schedule/2017/김해/2017_6.csv", encoding = 'cp949')
Jul_17 = pd.read_csv("C:/Data/schedule/2017/김해/2017_7.csv", encoding = 'cp949')
Aug_17 = pd.read_csv("C:/Data/schedule/2017/김해/2017_8.csv", encoding = 'cp949')
Sep_17 = pd.read_csv("C:/Data/schedule/2017/김해/2017_9.csv", encoding = 'cp949')
Oct_17 = pd.read_csv("C:/Data/schedule/2017/김해/2017_10.csv", encoding = 'cp949')
Nov_17 = pd.read_csv("C:/Data/schedule/2017/김해/2017_11.csv", encoding = 'cp949')
Dec_17 = pd.read_csv("C:/Data/schedule/2017/김해/2017_12.csv", encoding = 'cp949')

# 공백1, 공백2 열 삭제
Jan_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Feb_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Mar_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Apr_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
May_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jun_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jul_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Aug_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Sep_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Oct_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Nov_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Dec_17.drop(['공백1', '공백2'], axis = 1, inplace = True)

# 홀수행만 필터링(짝수행에는 빈값이 들어있음)
Jan_17 = Jan_17.iloc[::2, :]
Feb_17 = Feb_17.iloc[::2, :]
Mar_17 = Mar_17.iloc[::2, :]
Apr_17 = Apr_17.iloc[::2, :]
May_17 = May_17.iloc[::2, :]
Jun_17 = Jun_17.iloc[::2, :]
Jul_17 = Jul_17.iloc[::2, :]
Aug_17 = Aug_17.iloc[::2, :]
Sep_17 = Sep_17.iloc[::2, :]
Oct_17 = Oct_17.iloc[::2, :]
Nov_17 = Nov_17.iloc[::2, :]
Dec_17 = Dec_17.iloc[::2, :]

# 데이터 병합
pus_17 = pd.concat([Jan_17, Feb_17, Mar_17, Apr_17, May_17, Jun_17, Jul_17, Aug_17, Sep_17, Oct_17, Nov_17, Dec_17])
# 마지막으로 결측값 제거
pus_17.dropna(how='all')
# Out:
#              일자   항공사      편명                도착     계획     예상     출발  구분  현황
# 0    2017-01-31  대한항공  KE1002  제주(CJU)->김해(PUS)  08:50  08:50  09:11  여객  출발
# 2    2017-01-31  대한항공  KE1008  제주(CJU)->김해(PUS)  14:00  14:00  14:39  여객  지연
# 4    2017-01-31  대한항공  KE1014  제주(CJU)->김해(PUS)  18:10  18:44  18:40  여객  지연
# 6    2017-01-31  대한항공  KE1018  제주(CJU)->김해(PUS)  20:10  20:10  20:24  여객  출발
# 8    2017-01-31  대한항공  KE1020  제주(CJU)->김해(PUS)  20:40  20:40  20:57  여객  출발
# ..          ...   ...     ...               ...    ...    ...    ...  ..  ..
# 366  2017-12-01  대한항공  KE1020  제주(CJU)->김해(PUS)  20:50  20:50  21:07  여객  출발
# 368  2017-12-01  대한항공  KE1012  제주(CJU)->김해(PUS)  16:20  16:20  16:33  여객  출발
# 370  2017-12-01  대한항공  KE1014  제주(CJU)->김해(PUS)  18:10  18:10  18:35  여객  출발
# 372  2017-12-01  대한항공  KE1018  제주(CJU)->김해(PUS)  20:10  20:10  20:27  여객  출발
# 374  2017-12-01  대한항공  KE1020  제주(CJU)->김해(PUS)  20:50  20:50  21:07  여객  출발
#
# [2437 rows x 9 columns]

# %%
# 2018년 김해공항 데이터 
import pandas as pd

Jan_18 = pd.read_csv("C:/Data/schedule/2018/김해/2018_1.csv", encoding = 'cp949')
Feb_18 = pd.read_csv("C:/Data/schedule/2018/김해/2018_2.csv", encoding = 'cp949')
Mar_18 = pd.read_csv("C:/Data/schedule/2018/김해/2018_3.csv", encoding = 'cp949')
Apr_18 = pd.read_csv("C:/Data/schedule/2018/김해/2018_4.csv", encoding = 'cp949')
May_18 = pd.read_csv("C:/Data/schedule/2018/김해/2018_5.csv", encoding = 'cp949')
Jun_18 = pd.read_csv("C:/Data/schedule/2018/김해/2018_6.csv", encoding = 'cp949')
Jul_18 = pd.read_csv("C:/Data/schedule/2018/김해/2018_7.csv", encoding = 'cp949')
Aug_18 = pd.read_csv("C:/Data/schedule/2018/김해/2018_8.csv", encoding = 'cp949')
Sep_18 = pd.read_csv("C:/Data/schedule/2018/김해/2018_9.csv", encoding = 'cp949')
Oct_18 = pd.read_csv("C:/Data/schedule/2018/김해/2018_10.csv", encoding = 'cp949')
Nov_18 = pd.read_csv("C:/Data/schedule/2018/김해/2018_11.csv", encoding = 'cp949')
Dec_18 = pd.read_csv("C:/Data/schedule/2018/김해/2018_12.csv", encoding = 'cp949')

# 공백1, 공백2 열 삭제
Jan_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Feb_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Mar_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Apr_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
May_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jun_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jul_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Aug_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Sep_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Oct_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Nov_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Dec_18.drop(['공백1', '공백2'], axis = 1, inplace = True)

# 홀수행만 필터링(짝수행에는 빈값이 들어있음)
Jan_18 = Jan_18.iloc[::2, :]
Feb_18 = Feb_18.iloc[::2, :]
Mar_18 = Mar_18.iloc[::2, :]
Apr_18 = Apr_18.iloc[::2, :]
May_18 = May_18.iloc[::2, :]
Jun_18 = Jun_18.iloc[::2, :]
Jul_18 = Jul_18.iloc[::2, :]
Aug_18 = Aug_18.iloc[::2, :]
Sep_18 = Sep_18.iloc[::2, :]
Oct_18 = Oct_18.iloc[::2, :]
Nov_18 = Nov_18.iloc[::2, :]
Dec_18 = Dec_18.iloc[::2, :]

# 데이터 병합
pus_18 = pd.concat([Jan_18, Feb_18, Mar_18, Apr_18, May_18, Jun_18, Jul_18, Aug_18, Sep_18, Oct_18, Nov_18, Dec_18])
# 마지막으로 결측값 제거
pus_18.dropna(how='all')
# Out:
#              일자   항공사      편명                도착     계획     예상     출발  구분  현황
# 0    2018-01-31  대한항공  KE1002  제주(CJU)->김해(PUS)  08:50  08:50  09:07  여객  출발
# 2    2018-01-31  대한항공  KE1008  제주(CJU)->김해(PUS)  14:00  14:00  14:27  여객  출발
# 4    2018-01-31  대한항공  KE1014  제주(CJU)->김해(PUS)  18:10  18:10  18:28  여객  출발
# 6    2018-01-31  대한항공  KE1018  제주(CJU)->김해(PUS)  20:10  20:10  20:30  여객  출발
# 8    2018-01-31  대한항공  KE1020  제주(CJU)->김해(PUS)  20:50  20:50  21:08  여객  출발
# ..          ...   ...     ...               ...    ...    ...    ...  ..  ..
# 356  2018-12-01  대한항공  KE1004  제주(CJU)->김해(PUS)  14:00  14:00  14:15  여객  출발
# 358  2018-12-01  대한항공  KE1006  제주(CJU)->김해(PUS)  16:30  16:30  16:39  여객  출발
# 360  2018-12-01  대한항공  KE1008  제주(CJU)->김해(PUS)  18:10  18:10  18:29  여객  출발
# 362  2018-12-01  대한항공  KE1010  제주(CJU)->김해(PUS)  20:10  20:10  20:31  여객  출발
# 364  2018-12-01  대한항공  KE1012  제주(CJU)->김해(PUS)  20:50  20:50  21:10  여객  출발
#
# [2406 rows x 9 columns]

# %%
# 2019년 김해공항 데이터 
import pandas as pd

Jan_19 = pd.read_csv("C:/Data/schedule/2019/김해/2019_1.csv", encoding = 'cp949')
Feb_19 = pd.read_csv("C:/Data/schedule/2019/김해/2019_2.csv", encoding = 'cp949')
Mar_19 = pd.read_csv("C:/Data/schedule/2019/김해/2019_3.csv", encoding = 'cp949')
Apr_19 = pd.read_csv("C:/Data/schedule/2019/김해/2019_4.csv", encoding = 'cp949')
May_19 = pd.read_csv("C:/Data/schedule/2019/김해/2019_5.csv", encoding = 'cp949')
Jun_19 = pd.read_csv("C:/Data/schedule/2019/김해/2019_6.csv", encoding = 'cp949')
Jul_19 = pd.read_csv("C:/Data/schedule/2019/김해/2019_7.csv", encoding = 'cp949')
Aug_19 = pd.read_csv("C:/Data/schedule/2019/김해/2019_8.csv", encoding = 'cp949')
Sep_19 = pd.read_csv("C:/Data/schedule/2019/김해/2019_9.csv", encoding = 'cp949')
Oct_19 = pd.read_csv("C:/Data/schedule/2019/김해/2019_10.csv", encoding = 'cp949')
Nov_19 = pd.read_csv("C:/Data/schedule/2019/김해/2019_11.csv", encoding = 'cp949')
Dec_19 = pd.read_csv("C:/Data/schedule/2019/김해/2019_12.csv", encoding = 'cp949')

# 공백1, 공백2 열 삭제
Jan_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Feb_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Mar_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Apr_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
May_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jun_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jul_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Aug_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Sep_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Oct_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Nov_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Dec_19.drop(['공백1', '공백2'], axis = 1, inplace = True)

# 홀수행만 필터링(짝수행에는 빈값이 들어있음)
Jan_19 = Jan_18.iloc[::2, :]
Feb_19 = Feb_18.iloc[::2, :]
Mar_19 = Mar_18.iloc[::2, :]
Apr_19 = Apr_18.iloc[::2, :]
May_19 = May_18.iloc[::2, :]
Jun_19 = Jun_18.iloc[::2, :]
Jul_19 = Jul_18.iloc[::2, :]
Aug_19 = Aug_18.iloc[::2, :]
Sep_19 = Sep_18.iloc[::2, :]
Oct_19 = Oct_18.iloc[::2, :]
Nov_19 = Nov_18.iloc[::2, :]
Dec_19 = Dec_18.iloc[::2, :]

# 데이터 병합
pus_19 = pd.concat([Jan_19, Feb_19, Mar_19, Apr_19, May_19, Jun_19, Jul_19, Aug_19, Sep_19, Oct_19, Nov_19, Dec_19])
# 마지막으로 결측값 제거
pus_19.dropna(how='all')
# Out:
#              일자   항공사      편명                도착     계획     예상     출발  구분  현황
# 0    2018-01-31  대한항공  KE1002  제주(CJU)->김해(PUS)  08:50  08:50  09:07  여객  출발
# 4    2018-01-31  대한항공  KE1014  제주(CJU)->김해(PUS)  18:10  18:10  18:28  여객  출발
# 8    2018-01-31  대한항공  KE1020  제주(CJU)->김해(PUS)  20:50  20:50  21:08  여객  출발
# 12   2018-01-30  대한항공  KE1008  제주(CJU)->김해(PUS)  14:00  14:00  14:18  여객  출발
# 16   2018-01-30  대한항공  KE1018  제주(CJU)->김해(PUS)  20:10  20:10  20:22  여객  출발
# ..          ...   ...     ...               ...    ...    ...    ...  ..  ..
# 348  2018-12-02  대한항공  KE1008  제주(CJU)->김해(PUS)  18:10  18:10  18:46  여객  지연
# 352  2018-12-02  대한항공  KE1012  제주(CJU)->김해(PUS)  20:50  20:50  21:06  여객  출발
# 356  2018-12-01  대한항공  KE1004  제주(CJU)->김해(PUS)  14:00  14:00  14:15  여객  출발
# 360  2018-12-01  대한항공  KE1008  제주(CJU)->김해(PUS)  18:10  18:10  18:29  여객  출발
# 364  2018-12-01  대한항공  KE1012  제주(CJU)->김해(PUS)  20:50  20:50  21:10  여객  출발
#
# [1205 rows x 9 columns]

# %%
# 2020년 김해공항 데이터 
import pandas as pd

Jan_20 = pd.read_csv("C:/Data/schedule/2020/김해/2020_1.csv", encoding = 'cp949')
Feb_20 = pd.read_csv("C:/Data/schedule/2020/김해/2020_2.csv", encoding = 'cp949')
Mar_20 = pd.read_csv("C:/Data/schedule/2020/김해/2020_3.csv", encoding = 'cp949')
Apr_20 = pd.read_csv("C:/Data/schedule/2020/김해/2020_4.csv", encoding = 'cp949')
May_20 = pd.read_csv("C:/Data/schedule/2020/김해/2020_5.csv", encoding = 'cp949')
Jun_20 = pd.read_csv("C:/Data/schedule/2020/김해/2020_6.csv", encoding = 'cp949')
Jul_20 = pd.read_csv("C:/Data/schedule/2020/김해/2020_7.csv", encoding = 'cp949')
Aug_20 = pd.read_csv("C:/Data/schedule/2020/김해/2020_8.csv", encoding = 'cp949')
Sep_20 = pd.read_csv("C:/Data/schedule/2020/김해/2020_9.csv", encoding = 'cp949')
Oct_20 = pd.read_csv("C:/Data/schedule/2020/김해/2020_10.csv", encoding = 'cp949')
Nov_20 = pd.read_csv("C:/Data/schedule/2020/김해/2020_11.csv", encoding = 'cp949')
Dec_20 = pd.read_csv("C:/Data/schedule/2020/김해/2020_12.csv", encoding = 'cp949')

# 공백1, 공백2 열 삭제
Jan_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Feb_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Mar_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Apr_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
May_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jun_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jul_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Aug_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Sep_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Oct_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Nov_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Dec_20.drop(['공백1', '공백2'], axis = 1, inplace = True)

# 홀수행만 필터링(짝수행에는 빈값이 들어있음)
Jan_20 = Jan_20.iloc[::2, :]
Feb_20 = Feb_20.iloc[::2, :]
Mar_20 = Mar_20.iloc[::2, :]
Apr_20 = Apr_20.iloc[::2, :]
May_20 = May_20.iloc[::2, :]
Jun_20 = Jun_20.iloc[::2, :]
Jul_20 = Jul_20.iloc[::2, :]
Aug_20 = Aug_20.iloc[::2, :]
Sep_20 = Sep_20.iloc[::2, :]
Oct_20 = Oct_20.iloc[::2, :]
Nov_20 = Nov_20.iloc[::2, :]
Dec_20 = Dec_20.iloc[::2, :]

# 데이터 병합
pus_20 = pd.concat([Jan_20, Feb_20, Mar_20, Apr_20, May_20, Jun_20, Jul_20, Aug_20, Sep_20, Oct_20, Nov_20, Dec_20])
# 마지막으로 결측값 제거
pus_20.dropna(how='all')
# Out:
#              일자   항공사      편명                도착     계획     예상     출발  구분  현황
# 0    2020-01-31  대한항공  KE1002  제주(CJU)->김해(PUS)  08:50  08:50  09:06  여객  출발
# 2    2020-01-31  대한항공  KE1004  제주(CJU)->김해(PUS)  14:00  14:00  14:10  여객  출발
# 4    2020-01-31  대한항공  KE1006  제주(CJU)->김해(PUS)  16:30  16:30  16:38  여객  출발
# 6    2020-01-31  대한항공  KE1008  제주(CJU)->김해(PUS)  18:10  18:10  18:24  여객  출발
# 8    2020-01-31  대한항공  KE1010  제주(CJU)->김해(PUS)  20:10  20:10  20:25  여객  출발
# ..          ...   ...     ...               ...    ...    ...    ...  ..  ..
# 292  2020-12-01  대한항공  KE1022  제주(CJU)->김해(PUS)  15:00  15:00  15:14  여객  출발
# 294  2020-12-01  대한항공  KE1024  제주(CJU)->김해(PUS)  16:55  16:55  17:12  여객  출발
# 296  2020-12-01  대한항공  KE1028  제주(CJU)->김해(PUS)  18:30  18:30  18:40  여객  출발
# 298  2020-12-01  대한항공  KE1032  제주(CJU)->김해(PUS)  20:20  20:20  20:33  여객  출발
# 300  2020-12-01  대한항공  KE1034  제주(CJU)->김해(PUS)  20:50  20:50  21:10  여객  출발
#
# [2261 rows x 9 columns]

# %%
# 2021년 김해공항 데이터 
import pandas as pd

Jan_21 = pd.read_csv("C:/Data/schedule/2021/김해/2021_1.csv", encoding = 'cp949')
Feb_21 = pd.read_csv("C:/Data/schedule/2021/김해/2021_2.csv", encoding = 'cp949')
Mar_21 = pd.read_csv("C:/Data/schedule/2021/김해/2021_3.csv", encoding = 'cp949')
Apr_21 = pd.read_csv("C:/Data/schedule/2021/김해/2021_4.csv", encoding = 'cp949')
May_21 = pd.read_csv("C:/Data/schedule/2021/김해/2021_5.csv", encoding = 'cp949')
Jun_21 = pd.read_csv("C:/Data/schedule/2021/김해/2021_6.csv", encoding = 'cp949')
Jul_21 = pd.read_csv("C:/Data/schedule/2021/김해/2021_7.csv", encoding = 'cp949')
Aug_21 = pd.read_csv("C:/Data/schedule/2021/김해/2021_8.csv", encoding = 'cp949')
Sep_21 = pd.read_csv("C:/Data/schedule/2021/김해/2021_9.csv", encoding = 'cp949')
Oct_21 = pd.read_csv("C:/Data/schedule/2021/김해/2021_10.csv", encoding = 'cp949')
Nov_21 = pd.read_csv("C:/Data/schedule/2021/김해/2021_11.csv", encoding = 'cp949')
Dec_21 = pd.read_csv("C:/Data/schedule/2021/김해/2021_12.csv", encoding = 'cp949')

# 공백1, 공백2 열 삭제
Jan_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Feb_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Mar_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Apr_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
May_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jun_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jul_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Aug_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Sep_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Oct_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Nov_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Dec_21.drop(['공백1', '공백2'], axis = 1, inplace = True)

# 홀수행만 필터링(짝수행에는 빈값이 들어있음)
Jan_21 = Jan_21.iloc[::2, :]
Feb_21 = Feb_21.iloc[::2, :]
Mar_21 = Mar_21.iloc[::2, :]
Apr_21 = Apr_21.iloc[::2, :]
May_21 = May_21.iloc[::2, :]
Jun_21 = Jun_21.iloc[::2, :]
Jul_21 = Jul_21.iloc[::2, :]
Aug_21 = Aug_21.iloc[::2, :]
Sep_21 = Sep_21.iloc[::2, :]
Oct_21 = Oct_21.iloc[::2, :]
Nov_21 = Nov_21.iloc[::2, :]
Dec_21 = Dec_21.iloc[::2, :]

# 데이터 병합
pus_21 = pd.concat([Jan_21, Feb_21, Mar_21, Apr_21, May_21, Jun_21, Jul_21, Aug_21, Sep_21, Oct_21, Nov_21, Dec_21])
# 마지막으로 결측값 제거
pus_21.dropna(how='all')
# Out:
#              일자   항공사      편명                도착     계획     예상     출발  구분  현황
# 0    2021-01-31  대한항공  KE1016  제주(CJU)->김해(PUS)  13:40  13:40  13:50  여객  출발
# 2    2021-01-31  대한항공  KE1024  제주(CJU)->김해(PUS)  16:55  16:55  17:10  여객  출발
# 4    2021-01-31  대한항공  KE1028  제주(CJU)->김해(PUS)  18:30  18:30  18:51  여객  출발
# 6    2021-01-31  대한항공  KE1032  제주(CJU)->김해(PUS)  20:20  20:20  20:29  여객  출발
# 8    2021-01-31  대한항공  KE1034  제주(CJU)->김해(PUS)  20:50  20:50  21:00  여객  출발
# ..          ...   ...     ...               ...    ...    ...    ...  ..  ..
# 546  2021-12-01  대한항공  KE1022  제주(CJU)->김해(PUS)  14:30  14:30  14:45  여객  출발
# 548  2021-12-01  대한항공  KE1024  제주(CJU)->김해(PUS)  16:25  16:25  16:32  여객  출발
# 550  2021-12-01  대한항공  KE1028  제주(CJU)->김해(PUS)  17:45  17:45  18:04  여객  출발
# 552  2021-12-01  대한항공  KE1032  제주(CJU)->김해(PUS)  20:10  20:10  20:19  여객  출발
# 554  2021-12-01  대한항공  KE1034  제주(CJU)->김해(PUS)  21:00  21:00  21:10  여객  출발
#
# [2651 rows x 9 columns]

# %%
# 김해공항 2017 ~ 2021년도 데이터 병합
pus = pd.concat([pus_17, pus_18, pus_19, pus_20, pus_21])
pus
# Out:
#              일자   항공사      편명                도착     계획     예상     출발  구분  현황
# 0    2017-01-31  대한항공  KE1002  제주(CJU)->김해(PUS)  08:50  08:50  09:11  여객  출발
# 2    2017-01-31  대한항공  KE1008  제주(CJU)->김해(PUS)  14:00  14:00  14:39  여객  지연
# 4    2017-01-31  대한항공  KE1014  제주(CJU)->김해(PUS)  18:10  18:44  18:40  여객  지연
# 6    2017-01-31  대한항공  KE1018  제주(CJU)->김해(PUS)  20:10  20:10  20:24  여객  출발
# 8    2017-01-31  대한항공  KE1020  제주(CJU)->김해(PUS)  20:40  20:40  20:57  여객  출발
# ..          ...   ...     ...               ...    ...    ...    ...  ..  ..
# 546  2021-12-01  대한항공  KE1022  제주(CJU)->김해(PUS)  14:30  14:30  14:45  여객  출발
# 548  2021-12-01  대한항공  KE1024  제주(CJU)->김해(PUS)  16:25  16:25  16:32  여객  출발
# 550  2021-12-01  대한항공  KE1028  제주(CJU)->김해(PUS)  17:45  17:45  18:04  여객  출발
# 552  2021-12-01  대한항공  KE1032  제주(CJU)->김해(PUS)  20:10  20:10  20:19  여객  출발
# 554  2021-12-01  대한항공  KE1034  제주(CJU)->김해(PUS)  21:00  21:00  21:10  여객  출발
#
# [11105 rows x 9 columns]

# %% [markdown]
# ### 청주공항 데이터 전처리
# * 현재 상황
#     - 결측치 제거 필요
#     - 항공 스케줄 데이터가 연도별, 월별로 나뉘어 있음 => 데이터 병합 필요

# %%
# 2017년 청주공항 데이터 
import pandas as pd

Jan_17 = pd.read_csv("C:/Data/schedule/2017/청주/2017_1.csv", encoding = 'cp949')
Feb_17 = pd.read_csv("C:/Data/schedule/2017/청주/2017_2.csv", encoding = 'cp949')
Mar_17 = pd.read_csv("C:/Data/schedule/2017/청주/2017_3.csv", encoding = 'cp949')
Apr_17 = pd.read_csv("C:/Data/schedule/2017/청주/2017_4.csv", encoding = 'cp949')
May_17 = pd.read_csv("C:/Data/schedule/2017/청주/2017_5.csv", encoding = 'cp949')
Jun_17 = pd.read_csv("C:/Data/schedule/2017/청주/2017_6.csv", encoding = 'cp949')
Jul_17 = pd.read_csv("C:/Data/schedule/2017/청주/2017_7.csv", encoding = 'cp949')
Aug_17 = pd.read_csv("C:/Data/schedule/2017/청주/2017_8.csv", encoding = 'cp949')
Sep_17 = pd.read_csv("C:/Data/schedule/2017/청주/2017_9.csv", encoding = 'cp949')
Oct_17 = pd.read_csv("C:/Data/schedule/2017/청주/2017_10.csv", encoding = 'cp949')
Nov_17 = pd.read_csv("C:/Data/schedule/2017/청주/2017_11.csv", encoding = 'cp949')
Dec_17 = pd.read_csv("C:/Data/schedule/2017/청주/2017_12.csv", encoding = 'cp949')

# 공백1, 공백2 열 삭제
Jan_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Feb_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Mar_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Apr_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
May_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jun_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jul_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Aug_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Sep_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Oct_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Nov_17.drop(['공백1', '공백2'], axis = 1, inplace = True)
Dec_17.drop(['공백1', '공백2'], axis = 1, inplace = True)

# 홀수행만 필터링(짝수행에는 빈값이 들어있음)
Jan_17 = Jan_17.iloc[::2, :]
Feb_17 = Feb_17.iloc[::2, :]
Mar_17 = Mar_17.iloc[::2, :]
Apr_17 = Apr_17.iloc[::2, :]
May_17 = May_17.iloc[::2, :]
Jun_17 = Jun_17.iloc[::2, :]
Jul_17 = Jul_17.iloc[::2, :]
Aug_17 = Aug_17.iloc[::2, :]
Sep_17 = Sep_17.iloc[::2, :]
Oct_17 = Oct_17.iloc[::2, :]
Nov_17 = Nov_17.iloc[::2, :]
Dec_17 = Dec_17.iloc[::2, :]

# 데이터 병합
cjj_17 = pd.concat([Jan_17, Feb_17, Mar_17, Apr_17, May_17, Jun_17, Jul_17, Aug_17, Sep_17, Oct_17, Nov_17, Dec_17])
# 마지막으로 결측값 제거
cjj_17.dropna(how='all')
# Out:
#              일자   항공사      편명                도착     계획     예상     출발  구분  현황
# 0    2017-01-31  대한항공  KE1952  제주(CJU)->청주(CJJ)  10:05  10:05  10:31  여객  출발
# 2    2017-01-31  대한항공  KE1954  제주(CJU)->청주(CJJ)  13:25  14:13  14:16  여객  지연
# 4    2017-01-31  대한항공  KE1956  제주(CJU)->청주(CJJ)  16:45  17:30  17:30  여객  지연
# 6    2017-01-31  대한항공  KE1958  제주(CJU)->청주(CJJ)  20:25  20:25  20:41  여객  출발
# 8    2017-01-30  대한항공  KE1952  제주(CJU)->청주(CJJ)  10:05  10:05  10:24  여객  출발
# ..          ...   ...     ...               ...    ...    ...    ...  ..  ..
# 258  2017-12-02  대한항공  KE1958  제주(CJU)->청주(CJJ)  20:25  20:25  20:44  여객  출발
# 260  2017-12-01  대한항공  KE1952  제주(CJU)->청주(CJJ)  09:55  09:55  10:11  여객  출발
# 262  2017-12-01  대한항공  KE1954  제주(CJU)->청주(CJJ)  11:25  11:25  11:47  여객  출발
# 264  2017-12-01  대한항공  KE1956  제주(CJU)->청주(CJJ)  16:00  16:00  16:27  여객  출발
# 266  2017-12-01  대한항공  KE1958  제주(CJU)->청주(CJJ)  20:25  20:25  20:40  여객  출발
#
# [1488 rows x 9 columns]

# %%
# 2018년 청주공항 데이터 
import pandas as pd

Jan_18 = pd.read_csv("C:/Data/schedule/2018/청주/2018_1.csv", encoding = 'cp949')
Feb_18 = pd.read_csv("C:/Data/schedule/2018/청주/2018_2.csv", encoding = 'cp949')
Mar_18 = pd.read_csv("C:/Data/schedule/2018/청주/2018_3.csv", encoding = 'cp949')
Apr_18 = pd.read_csv("C:/Data/schedule/2018/청주/2018_4.csv", encoding = 'cp949')
May_18 = pd.read_csv("C:/Data/schedule/2018/청주/2018_5.csv", encoding = 'cp949')
Jun_18 = pd.read_csv("C:/Data/schedule/2018/청주/2018_6.csv", encoding = 'cp949')
Jul_18 = pd.read_csv("C:/Data/schedule/2018/청주/2018_7.csv", encoding = 'cp949')
Aug_18 = pd.read_csv("C:/Data/schedule/2018/청주/2018_8.csv", encoding = 'cp949')
Sep_18 = pd.read_csv("C:/Data/schedule/2018/청주/2018_9.csv", encoding = 'cp949')
Oct_18 = pd.read_csv("C:/Data/schedule/2018/청주/2018_10.csv", encoding = 'cp949')
Nov_18 = pd.read_csv("C:/Data/schedule/2018/청주/2018_11.csv", encoding = 'cp949')
Dec_18 = pd.read_csv("C:/Data/schedule/2018/청주/2018_12.csv", encoding = 'cp949')

# 공백1, 공백2 열 삭제
Jan_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Feb_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Mar_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Apr_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
May_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jun_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jul_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Aug_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Sep_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Oct_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Nov_18.drop(['공백1', '공백2'], axis = 1, inplace = True)
Dec_18.drop(['공백1', '공백2'], axis = 1, inplace = True)

# 홀수행만 필터링(짝수행에는 빈값이 들어있음)
Jan_18 = Jan_18.iloc[::2, :]
Feb_18 = Feb_18.iloc[::2, :]
Mar_18 = Mar_18.iloc[::2, :]
Apr_18 = Apr_18.iloc[::2, :]
May_18 = May_18.iloc[::2, :]
Jun_18 = Jun_18.iloc[::2, :]
Jul_18 = Jul_18.iloc[::2, :]
Aug_18 = Aug_18.iloc[::2, :]
Sep_18 = Sep_18.iloc[::2, :]
Oct_18 = Oct_18.iloc[::2, :]
Nov_18 = Nov_18.iloc[::2, :]
Dec_18 = Dec_18.iloc[::2, :]

# 데이터 병합
cjj_18 = pd.concat([Jan_18, Feb_18, Mar_18, Apr_18, May_18, Jun_18, Jul_18, Aug_18, Sep_18, Oct_18, Nov_18, Dec_18])
# 마지막으로 결측값 제거
cjj_18.dropna(how='all')
# Out:
#              일자   항공사      편명                도착     계획     예상     출발  구분  현황
# 0    2018-01-31  대한항공  KE1952  제주(CJU)->청주(CJJ)  09:55  09:55  10:09  여객  출발
# 2    2018-01-31  대한항공  KE1954  제주(CJU)->청주(CJJ)  13:25  13:25  13:44  여객  출발
# 4    2018-01-31  대한항공  KE1956  제주(CJU)->청주(CJJ)  16:50  16:50  17:14  여객  출발
# 6    2018-01-31  대한항공  KE1958  제주(CJU)->청주(CJJ)  20:25  20:25  20:35  여객  출발
# 8    2018-01-30  대한항공  KE1952  제주(CJU)->청주(CJJ)  09:55  09:55  10:17  여객  출발
# ..          ...   ...     ...               ...    ...    ...    ...  ..  ..
# 258  2018-12-02  대한항공  KE1958  제주(CJU)->청주(CJJ)  20:25  20:25  20:45  여객  출발
# 260  2018-12-01  대한항공  KE1952  제주(CJU)->청주(CJJ)  09:45  09:45  10:00  여객  출발
# 262  2018-12-01  대한항공  KE1954  제주(CJU)->청주(CJJ)  13:25  13:25  13:41  여객  출발
# 264  2018-12-01  대한항공  KE1956  제주(CJU)->청주(CJJ)  16:55  16:55  17:18  여객  출발
# 266  2018-12-01  대한항공  KE1958  제주(CJU)->청주(CJJ)  20:25  20:25  20:41  여객  출발
#
# [1471 rows x 9 columns]

# %%
# 2019년 청주공항 데이터 
import pandas as pd

Jan_19 = pd.read_csv("C:/Data/schedule/2019/청주/2019_1.csv", encoding = 'cp949')
Feb_19 = pd.read_csv("C:/Data/schedule/2019/청주/2019_2.csv", encoding = 'cp949')
Mar_19 = pd.read_csv("C:/Data/schedule/2019/청주/2019_3.csv", encoding = 'cp949')
Apr_19 = pd.read_csv("C:/Data/schedule/2019/청주/2019_4.csv", encoding = 'cp949')
May_19 = pd.read_csv("C:/Data/schedule/2019/청주/2019_5.csv", encoding = 'cp949')
Jun_19 = pd.read_csv("C:/Data/schedule/2019/청주/2019_6.csv", encoding = 'cp949')
Jul_19 = pd.read_csv("C:/Data/schedule/2019/청주/2019_7.csv", encoding = 'cp949')
Aug_19 = pd.read_csv("C:/Data/schedule/2019/청주/2019_8.csv", encoding = 'cp949')
Sep_19 = pd.read_csv("C:/Data/schedule/2019/청주/2019_9.csv", encoding = 'cp949')
Oct_19 = pd.read_csv("C:/Data/schedule/2019/청주/2019_10.csv", encoding = 'cp949')
Nov_19 = pd.read_csv("C:/Data/schedule/2019/청주/2019_11.csv", encoding = 'cp949')
Dec_19 = pd.read_csv("C:/Data/schedule/2019/청주/2019_12.csv", encoding = 'cp949')

# 공백1, 공백2 열 삭제
Jan_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Feb_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Mar_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Apr_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
May_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jun_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jul_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Aug_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Sep_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Oct_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Nov_19.drop(['공백1', '공백2'], axis = 1, inplace = True)
Dec_19.drop(['공백1', '공백2'], axis = 1, inplace = True)

# 홀수행만 필터링(짝수행에는 빈값이 들어있음)
Jan_19 = Jan_18.iloc[::2, :]
Feb_19 = Feb_18.iloc[::2, :]
Mar_19 = Mar_18.iloc[::2, :]
Apr_19 = Apr_18.iloc[::2, :]
May_19 = May_18.iloc[::2, :]
Jun_19 = Jun_18.iloc[::2, :]
Jul_19 = Jul_18.iloc[::2, :]
Aug_19 = Aug_18.iloc[::2, :]
Sep_19 = Sep_18.iloc[::2, :]
Oct_19 = Oct_18.iloc[::2, :]
Nov_19 = Nov_18.iloc[::2, :]
Dec_19 = Dec_18.iloc[::2, :]

# 데이터 병합
cjj_19 = pd.concat([Jan_19, Feb_19, Mar_19, Apr_19, May_19, Jun_19, Jul_19, Aug_19, Sep_19, Oct_19, Nov_19, Dec_19])
# 마지막으로 결측값 제거
cjj_19.dropna(how='all')
# Out:
#              일자   항공사      편명                도착     계획     예상     출발  구분  현황
# 0    2018-01-31  대한항공  KE1952  제주(CJU)->청주(CJJ)  09:55  09:55  10:09  여객  출발
# 4    2018-01-31  대한항공  KE1956  제주(CJU)->청주(CJJ)  16:50  16:50  17:14  여객  출발
# 8    2018-01-30  대한항공  KE1952  제주(CJU)->청주(CJJ)  09:55  09:55  10:17  여객  출발
# 12   2018-01-30  대한항공  KE1956  제주(CJU)->청주(CJJ)  16:50  16:50  17:10  여객  출발
# 16   2018-01-29  대한항공  KE1952  제주(CJU)->청주(CJJ)  09:55  09:55  10:15  여객  출발
# ..          ...   ...     ...               ...    ...    ...    ...  ..  ..
# 248  2018-12-03  대한항공  KE1956  제주(CJU)->청주(CJJ)  15:45  15:45  15:59  여객  출발
# 252  2018-12-02  대한항공  KE1952  제주(CJU)->청주(CJJ)  09:45  09:45  10:02  여객  출발
# 256  2018-12-02  대한항공  KE1956  제주(CJU)->청주(CJJ)  16:55  16:55  17:08  여객  출발
# 260  2018-12-01  대한항공  KE1952  제주(CJU)->청주(CJJ)  09:45  09:45  10:00  여객  출발
# 264  2018-12-01  대한항공  KE1956  제주(CJU)->청주(CJJ)  16:55  16:55  17:18  여객  출발
#
# [737 rows x 9 columns]

# %%
# 2020년 청주공항 데이터 
import pandas as pd

Jan_20 = pd.read_csv("C:/Data/schedule/2020/청주/2020_1.csv", encoding = 'cp949')
Feb_20 = pd.read_csv("C:/Data/schedule/2020/청주/2020_2.csv", encoding = 'cp949')
Mar_20 = pd.read_csv("C:/Data/schedule/2020/청주/2020_3.csv", encoding = 'cp949')
Apr_20 = pd.read_csv("C:/Data/schedule/2020/청주/2020_4.csv", encoding = 'cp949')
May_20 = pd.read_csv("C:/Data/schedule/2020/청주/2020_5.csv", encoding = 'cp949')
Jun_20 = pd.read_csv("C:/Data/schedule/2020/청주/2020_6.csv", encoding = 'cp949')
Jul_20 = pd.read_csv("C:/Data/schedule/2020/청주/2020_7.csv", encoding = 'cp949')
Aug_20 = pd.read_csv("C:/Data/schedule/2020/청주/2020_8.csv", encoding = 'cp949')
Sep_20 = pd.read_csv("C:/Data/schedule/2020/청주/2020_9.csv", encoding = 'cp949')
Oct_20 = pd.read_csv("C:/Data/schedule/2020/청주/2020_10.csv", encoding = 'cp949')
Nov_20 = pd.read_csv("C:/Data/schedule/2020/청주/2020_11.csv", encoding = 'cp949')
Dec_20 = pd.read_csv("C:/Data/schedule/2020/청주/2020_12.csv", encoding = 'cp949')

# 공백1, 공백2 열 삭제
Jan_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Feb_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Mar_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Apr_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
May_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jun_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jul_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Aug_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Sep_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Oct_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Nov_20.drop(['공백1', '공백2'], axis = 1, inplace = True)
Dec_20.drop(['공백1', '공백2'], axis = 1, inplace = True)

# 홀수행만 필터링(짝수행에는 빈값이 들어있음)
Jan_20 = Jan_20.iloc[::2, :]
Feb_20 = Feb_20.iloc[::2, :]
Mar_20 = Mar_20.iloc[::2, :]
Apr_20 = Apr_20.iloc[::2, :]
May_20 = May_20.iloc[::2, :]
Jun_20 = Jun_20.iloc[::2, :]
Jul_20 = Jul_20.iloc[::2, :]
Aug_20 = Aug_20.iloc[::2, :]
Sep_20 = Sep_20.iloc[::2, :]
Oct_20 = Oct_20.iloc[::2, :]
Nov_20 = Nov_20.iloc[::2, :]
Dec_20 = Dec_20.iloc[::2, :]

# 데이터 병합
cjj_20 = pd.concat([Jan_20, Feb_20, Mar_20, Apr_20, May_20, Jun_20, Jul_20, Aug_20, Sep_20, Oct_20, Nov_20, Dec_20])
# 마지막으로 결측값 제거
cjj_20.dropna(how='all')
# Out:
#              일자   항공사      편명                도착     계획     예상     출발  구분  현황
# 0    2020-01-31  대한항공  KE1952  제주(CJU)->청주(CJJ)   9:45   9:45   9:52  여객  출발
# 2    2020-01-31  대한항공  KE1954  제주(CJU)->청주(CJJ)  11:30  11:30  11:45  여객  출발
# 4    2020-01-31  대한항공  KE1956  제주(CJU)->청주(CJJ)  15:50  15:50  16:08  여객  출발
# 6    2020-01-31  대한항공  KE1958  제주(CJU)->청주(CJJ)  20:25  20:25  20:43  여객  출발
# 8    2020-01-30  대한항공  KE1952  제주(CJU)->청주(CJJ)   9:45   9:45  10:01  여객  출발
# ..          ...   ...     ...               ...    ...    ...    ...  ..  ..
# 170  2020-12-02  대한항공  KE1956  제주(CJU)->청주(CJJ)  14:45  14:45  15:01  여객  출발
# 172  2020-12-02  대한항공  KE1958  제주(CJU)->청주(CJJ)  16:45  16:45  16:57  여객  출발
# 174  2020-12-01  대한항공  KE1952  제주(CJU)->청주(CJJ)   7:25   7:25   7:41  여객  출발
# 176  2020-12-01  대한항공  KE1956  제주(CJU)->청주(CJJ)  14:45  14:45  14:57  여객  출발
# 178  2020-12-01  대한항공  KE1958  제주(CJU)->청주(CJJ)  16:45  16:45  16:56  여객  출발
#
# [1051 rows x 9 columns]

# %%
# 2021년 청주공항 데이터 
import pandas as pd

Jan_21 = pd.read_csv("C:/Data/schedule/2021/청주/2021_1.csv", encoding = 'cp949')
Feb_21 = pd.read_csv("C:/Data/schedule/2021/청주/2021_2.csv", encoding = 'cp949')
Mar_21 = pd.read_csv("C:/Data/schedule/2021/청주/2021_3.csv", encoding = 'cp949')
Apr_21 = pd.read_csv("C:/Data/schedule/2021/청주/2021_4.csv", encoding = 'cp949')
May_21 = pd.read_csv("C:/Data/schedule/2021/청주/2021_5.csv", encoding = 'cp949')
Jun_21 = pd.read_csv("C:/Data/schedule/2021/청주/2021_6.csv", encoding = 'cp949')
Jul_21 = pd.read_csv("C:/Data/schedule/2021/청주/2021_7.csv", encoding = 'cp949')
Aug_21 = pd.read_csv("C:/Data/schedule/2021/청주/2021_8.csv", encoding = 'cp949')
Sep_21 = pd.read_csv("C:/Data/schedule/2021/청주/2021_9.csv", encoding = 'cp949')
Oct_21 = pd.read_csv("C:/Data/schedule/2021/청주/2021_10.csv", encoding = 'cp949')
Nov_21 = pd.read_csv("C:/Data/schedule/2021/청주/2021_11.csv", encoding = 'cp949')
Dec_21 = pd.read_csv("C:/Data/schedule/2021/청주/2021_12.csv", encoding = 'cp949')

# 공백1, 공백2 열 삭제
Jan_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Feb_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Mar_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Apr_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
May_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jun_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Jul_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Aug_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Sep_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Oct_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Nov_21.drop(['공백1', '공백2'], axis = 1, inplace = True)
Dec_21.drop(['공백1', '공백2'], axis = 1, inplace = True)

# 홀수행만 필터링(짝수행에는 빈값이 들어있음)
Jan_21 = Jan_21.iloc[::2, :]
Feb_21 = Feb_21.iloc[::2, :]
Mar_21 = Mar_21.iloc[::2, :]
Apr_21 = Apr_21.iloc[::2, :]
May_21 = May_21.iloc[::2, :]
Jun_21 = Jun_21.iloc[::2, :]
Jul_21 = Jul_21.iloc[::2, :]
Aug_21 = Aug_21.iloc[::2, :]
Sep_21 = Sep_21.iloc[::2, :]
Oct_21 = Oct_21.iloc[::2, :]
Nov_21 = Nov_21.iloc[::2, :]
Dec_21 = Dec_21.iloc[::2, :]

# 데이터 병합
cjj_21 = pd.concat([Jan_21, Feb_21, Mar_21, Apr_21, May_21, Jun_21, Jul_21, Aug_21, Sep_21, Oct_21, Nov_21, Dec_21])
# 마지막으로 결측값 제거
cjj_21.dropna(how='all')
# Out:
#              일자   항공사      편명                도착     계획     예상     출발  구분  현황
# 0    2021-01-31  대한항공  KE1952  제주(CJU)->청주(CJJ)  07:25  07:25  07:36  여객  출발
# 2    2021-01-31  대한항공  KE1956  제주(CJU)->청주(CJJ)  14:45  14:45  14:50  여객  출발
# 4    2021-01-31  대한항공  KE1958  제주(CJU)->청주(CJJ)  16:45  16:45  16:55  여객  출발
# 6    2021-01-30  대한항공  KE1952  제주(CJU)->청주(CJJ)  07:25  07:25  07:29  여객  출발
# 8    2021-01-30  대한항공  KE1956  제주(CJU)->청주(CJJ)  14:45  14:45  14:50  여객  출발
# ..          ...   ...     ...               ...    ...    ...    ...  ..  ..
# 194  2021-12-02  대한항공  KE1958  제주(CJU)->청주(CJJ)  16:10  16:10  16:49  여객  지연
# 196  2021-12-01  대한항공  KE1952  제주(CJU)->청주(CJJ)  07:40  07:40  07:52  여객  출발
# 198  2021-12-01  대한항공  KE1956  제주(CJU)->청주(CJJ)  14:30  14:45  15:08  여객  지연
# 200  2021-12-01  대한항공  KE1958  제주(CJU)->청주(CJJ)  16:10  16:10  16:37  여객  출발
# 202  2021-12-01  대한항공  KE1958  제주(CJU)->청주(CJJ)  16:10  16:10  16:37  여객  출발
#
# [1116 rows x 9 columns]

# %%
# 청주공항 2017 ~ 2021년도 데이터 병합
cjj = pd.concat([cjj_17, cjj_18, cjj_19, cjj_20, cjj_21])
cjj
# Out:
#              일자   항공사      편명                도착     계획     예상     출발  구분  현황
# 0    2017-01-31  대한항공  KE1952  제주(CJU)->청주(CJJ)  10:05  10:05  10:31  여객  출발
# 2    2017-01-31  대한항공  KE1954  제주(CJU)->청주(CJJ)  13:25  14:13  14:16  여객  지연
# 4    2017-01-31  대한항공  KE1956  제주(CJU)->청주(CJJ)  16:45  17:30  17:30  여객  지연
# 6    2017-01-31  대한항공  KE1958  제주(CJU)->청주(CJJ)  20:25  20:25  20:41  여객  출발
# 8    2017-01-30  대한항공  KE1952  제주(CJU)->청주(CJJ)  10:05  10:05  10:24  여객  출발
# ..          ...   ...     ...               ...    ...    ...    ...  ..  ..
# 194  2021-12-02  대한항공  KE1958  제주(CJU)->청주(CJJ)  16:10  16:10  16:49  여객  지연
# 196  2021-12-01  대한항공  KE1952  제주(CJU)->청주(CJJ)  07:40  07:40  07:52  여객  출발
# 198  2021-12-01  대한항공  KE1956  제주(CJU)->청주(CJJ)  14:30  14:45  15:08  여객  지연
# 200  2021-12-01  대한항공  KE1958  제주(CJU)->청주(CJJ)  16:10  16:10  16:37  여객  출발
# 202  2021-12-01  대한항공  KE1958  제주(CJU)->청주(CJJ)  16:10  16:10  16:37  여객  출발
#
# [5919 rows x 9 columns]

# %%
schedule = pd.concat([kwj, gmp, pus, cjj])
schedule
# Out:
#              일자   항공사      편명                도착     계획     예상     출발  구분  현황
# 0    2017-01-31  대한항공  KE1902  제주(CJU)->광주(KWJ)   8:35   8:35   8:50  여객  출발
# 2    2017-01-31  대한항공  KE1904  제주(CJU)->광주(KWJ)  11:45  11:45  12:02  여객  출발
# 4    2017-01-31  대한항공  KE1906  제주(CJU)->광주(KWJ)  15:00  15:00  15:15  여객  출발
# 6    2017-01-31  대한항공  KE1900  제주(CJU)->광주(KWJ)  16:00  17:00  16:56  여객  지연
# 8    2017-01-31  대한항공  KE1908  제주(CJU)->광주(KWJ)  18:05  18:05  18:22  여객  출발
# ..          ...   ...     ...               ...    ...    ...    ...  ..  ..
# 194  2021-12-02  대한항공  KE1958  제주(CJU)->청주(CJJ)  16:10  16:10  16:49  여객  지연
# 196  2021-12-01  대한항공  KE1952  제주(CJU)->청주(CJJ)  07:40  07:40  07:52  여객  출발
# 198  2021-12-01  대한항공  KE1956  제주(CJU)->청주(CJJ)  14:30  14:45  15:08  여객  지연
# 200  2021-12-01  대한항공  KE1958  제주(CJU)->청주(CJJ)  16:10  16:10  16:37  여객  출발
# 202  2021-12-01  대한항공  KE1958  제주(CJU)->청주(CJJ)  16:10  16:10  16:37  여객  출발
#
# [72643 rows x 9 columns]

# %%
mask = schedule.현황 == "결항"
cancel = schedule[mask]
cancel
# Out:
#               일자   항공사      편명                도착     계획     예상     출발  구분  현황
# 20    2017-09-28  대한항공  KE1902  제주(CJU)->광주(KWJ)   8:45   8:45   9:04  여객  결항
# 0     2017-10-31  대한항공  KE1902  제주(CJU)->광주(KWJ)   8:35    NaN    NaN  여객  결항
# 2     2017-10-31  대한항공  KE1904  제주(CJU)->광주(KWJ)  11:45    NaN    NaN  여객  결항
# 4     2017-10-31  대한항공  KE1906  제주(CJU)->광주(KWJ)  15:00    NaN    NaN  여객  결항
# 6     2017-10-31  대한항공  KE1900  제주(CJU)->광주(KWJ)  16:00    NaN    NaN  여객  결항
# 8     2017-10-31  대한항공  KE1908  제주(CJU)->광주(KWJ)  18:10    NaN    NaN  여객  결항
# 92    2017-11-21  대한항공  KE1904  제주(CJU)->광주(KWJ)  11:45  11:45    NaN  여객  결항
# 290   2017-11-01  대한항공  KE1902  제주(CJU)->광주(KWJ)   8:35    NaN    NaN  여객  결항
# 244   2017-12-07  대한항공  KE1906  제주(CJU)->광주(KWJ)  15:00  15:00    NaN  여객  결항
# 472   2017-01-22  대한항공  KE1252  제주(CJU)->김포(GMP)  10:45    NaN    NaN  여객  결항
# 578   2017-01-20  대한항공  KE1258  제주(CJU)->김포(GMP)  14:20    NaN    NaN  여객  결항
# ...

# %% [markdown]
# #### 위의 결과에서 나온 NaN가 포함된 행은 결과에 영향을 미치지 않지만, csv 변환 시 데이터가 밀리는 현상이 발생할 가능성이 있기 때문에 다른 값으로 대체해주어야 함

# %%
schedule = schedule.fillna("X")
schedule
# Out:
#              일자   항공사      편명                도착     계획     예상     출발  구분  현황
# 0    2017-01-31  대한항공  KE1902  제주(CJU)->광주(KWJ)   8:35   8:35   8:50  여객  출발
# 2    2017-01-31  대한항공  KE1904  제주(CJU)->광주(KWJ)  11:45  11:45  12:02  여객  출발
# 4    2017-01-31  대한항공  KE1906  제주(CJU)->광주(KWJ)  15:00  15:00  15:15  여객  출발
# 6    2017-01-31  대한항공  KE1900  제주(CJU)->광주(KWJ)  16:00  17:00  16:56  여객  지연
# 8    2017-01-31  대한항공  KE1908  제주(CJU)->광주(KWJ)  18:05  18:05  18:22  여객  출발
# ..          ...   ...     ...               ...    ...    ...    ...  ..  ..
# 194  2021-12-02  대한항공  KE1958  제주(CJU)->청주(CJJ)  16:10  16:10  16:49  여객  지연
# 196  2021-12-01  대한항공  KE1952  제주(CJU)->청주(CJJ)  07:40  07:40  07:52  여객  출발
# 198  2021-12-01  대한항공  KE1956  제주(CJU)->청주(CJJ)  14:30  14:45  15:08  여객  지연
# 200  2021-12-01  대한항공  KE1958  제주(CJU)->청주(CJJ)  16:10  16:10  16:37  여객  출발
# 202  2021-12-01  대한항공  KE1958  제주(CJU)->청주(CJJ)  16:10  16:10  16:37  여객  출발
#
# [72643 rows x 9 columns]

# %%
mask = schedule.현황 == "결항"
cancel = schedule[mask]
cancel
# Out:
#               일자   항공사      편명                도착     계획     예상     출발  구분  현황
# 20    2017-09-28  대한항공  KE1902  제주(CJU)->광주(KWJ)   8:45   8:45   9:04  여객  결항
# 0     2017-10-31  대한항공  KE1902  제주(CJU)->광주(KWJ)   8:35      X      X  여객  결항
# 2     2017-10-31  대한항공  KE1904  제주(CJU)->광주(KWJ)  11:45      X      X  여객  결항
# 4     2017-10-31  대한항공  KE1906  제주(CJU)->광주(KWJ)  15:00      X      X  여객  결항
# 6     2017-10-31  대한항공  KE1900  제주(CJU)->광주(KWJ)  16:00      X      X  여객  결항
# 8     2017-10-31  대한항공  KE1908  제주(CJU)->광주(KWJ)  18:10      X      X  여객  결항
# 92    2017-11-21  대한항공  KE1904  제주(CJU)->광주(KWJ)  11:45  11:45      X  여객  결항
# 290   2017-11-01  대한항공  KE1902  제주(CJU)->광주(KWJ)   8:35      X      X  여객  결항
# 244   2017-12-07  대한항공  KE1906  제주(CJU)->광주(KWJ)  15:00  15:00      X  여객  결항
# 472   2017-01-22  대한항공  KE1252  제주(CJU)->김포(GMP)  10:45      X      X  여객  결항
# 578   2017-01-20  대한항공  KE1258  제주(CJU)->김포(GMP)  14:20      X      X  여객  결항
# ...

# %%
# '일자' 컬럼 파싱
schedule["연도"] = schedule.일자.str.split('-').str[0]
schedule["월"] = schedule.일자.str.split('-').str[1]
schedule['일'] = schedule.일자.str.split('-').str[2]

# '일자' 컬럼 삭제
schedule.drop('일자', axis = 1, inplace = True)

# 컬럼 순서 변경
schedule = schedule[['연도', '월', '일', '항공사', '편명', '도착', '계획', '예상', '출발', '구분', '현황']]
schedule
# Out:
#        연도   월   일   항공사      편명                도착     계획     예상     출발  구분  현황
# 0    2017  01  31  대한항공  KE1902  제주(CJU)->광주(KWJ)   8:35   8:35   8:50  여객  출발
# 2    2017  01  31  대한항공  KE1904  제주(CJU)->광주(KWJ)  11:45  11:45  12:02  여객  출발
# 4    2017  01  31  대한항공  KE1906  제주(CJU)->광주(KWJ)  15:00  15:00  15:15  여객  출발
# 6    2017  01  31  대한항공  KE1900  제주(CJU)->광주(KWJ)  16:00  17:00  16:56  여객  지연
# 8    2017  01  31  대한항공  KE1908  제주(CJU)->광주(KWJ)  18:05  18:05  18:22  여객  출발
# ..    ...  ..  ..   ...     ...               ...    ...    ...    ...  ..  ..
# 194  2021  12  02  대한항공  KE1958  제주(CJU)->청주(CJJ)  16:10  16:10  16:49  여객  지연
# 196  2021  12  01  대한항공  KE1952  제주(CJU)->청주(CJJ)  07:40  07:40  07:52  여객  출발
# 198  2021  12  01  대한항공  KE1956  제주(CJU)->청주(CJJ)  14:30  14:45  15:08  여객  지연
# 200  2021  12  01  대한항공  KE1958  제주(CJU)->청주(CJJ)  16:10  16:10  16:37  여객  출발
# 202  2021  12  01  대한항공  KE1958  제주(CJU)->청주(CJJ)  16:10  16:10  16:37  여객  출발
#
# ...

# %%
# 한글깨짐 방지를 위해 encoding = "utf-8-sig" 로 설정
schedule.to_csv("C:\Data\schedule_pre\schedule.csv", encoding = "utf-8-sig")
